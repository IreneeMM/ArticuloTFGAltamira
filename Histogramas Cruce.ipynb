# %% [markdown]
# ### Histogramas Cruce:
# Contenido del fichero:
# 1. Histogramas de la temperatura de Cruce sin suavizar
# 2. Histogramas de la temperatura de Cruce suavizada
# 3. Histogramas de la cantidad de CO2 de Cruce sin suavizar
# 4. Histogramas de la cantidad de CO2 de Cruce suavizada
# 5. Histogramas de la temperatura del Ramal sin suavizar
# 6. Histogramas de la temperatura del Ramal suavizada

# %%
# Imports:
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Variables que se pueden modificar:
divisiones = 10 #Numero de intervalos en los que se dividen los datos a representar en el histograma

# %% [markdown]
# # 1. Histogramas de la temperatura de Cruce sin suavizar

# %% [markdown]
# En esta variable se explica qué hace cada función. Esto se puede extrapolar al resto de casos, en todos los bloques las funciones hacen los mismo pero para diferentes variables.

# %% [markdown]
# ### Sacar el máximo de veces que se repite un dato en los histogramas:

# %%
#Fijar variables de inicio:
m=0 #Máximo de datos por columna hasta este momento
minVariable=100000000000#Minimo  para comparar de la variable a representar
maxVariable=0#Máximo para comparar de la variable a representar

def AlturaTCruce(FicheroCruce, m, divisiones, minVariable, maxVariable):
    '''
    Pasando los atributos:
    1) Fichero Cruce: Archivo excel con datos de un mes del Cruce de la cueva Altamira
    2) m: Fija el número de datos por columna para después poder contabilizarlos y sacar la altura 
    máxima, es decir, el máximo de datos que se repiten por intervalo de histograma
    3) divisiones: Número de intervalos en los que se quiere dividir el rango de datos de la variable
    4) minVariable: Mínimo fijado con el que comparar la varible a representar para obtener la anchura
    del dataframe en el eje de abscisas
    5) maxVariable: Máximo fijado con el que comparar la varible a representar para obtener la anchura
    del dataframe en el eje de abscisas
    
    La función obtiene la altura máxima del histograma, es decir, el número de datos que se repiten en
    el intervalo más poblado, y la anchura de la variable a representar, el valor máximo y mínimo de 
    esta. Los tres valores obtenidos se comparan con m, minVariable y maxVariable, reescribiendolos en 
    caso de que la altura obtenida sea mayor que m, el valor mínimo de la variable sea menor que 
    minVarible o el valor máximo sea mayor que MaxVariable.
    
    '''
    #Igualar la escala en y:
#     print('---------------------------------------------------------------')
    df = pd.read_excel(FicheroCruce)
    min_relativo=df["Temperatura D (° C)"].min()
    max_relativo=df["Temperatura D (° C)"].max()
    bins = np.linspace(min_relativo, max_relativo, divisiones)
    hist, bins = np.histogram(df["Temperatura D (° C)"], bins=bins)
#     print('Máximo de datos por columna hasta ahora:', m)
    for i in range(len(hist)):
#         print(f"Intervalo {i+1}: {hist[i]} datos")
        if hist[i]>m:
            m=hist[i]
    #Igualar la escala en x:
    if min_relativo<minVariable:
        minVariable=min_relativo
    if max_relativo>maxVariable:
        maxVariable=max_relativo
    
    return m, minVariable, maxVariable

# %%
# Prueba
# m, minVariable, maxVariable = AlturaTCruce("./altamira/2020/10.OCTUBRE/ZONA CRUCE.xlsx", m, divisiones, minVariable, maxVariable)

# %%
# 2020
m, minVariable, maxVariable = AlturaTCruce("./altamira/2020/10.OCTUBRE/ZONA CRUCE.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTCruce("./altamira/2020/11.NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTCruce("./altamira/2020/12.DICIEMBRE/ZONA CRUCE.xlsx", m, divisiones, minVariable, maxVariable)
#2021
m, minVariable, maxVariable = AlturaTCruce("./altamira/2021/1.ENERO/ZONA CRUCE ENERO.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTCruce("./altamira/2021/2.FEBRERO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTCruce("./altamira/2021/3.MARZO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTCruce("./altamira/2021/4.ABRIL/ZONA CRUCE.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTCruce("./altamira/2021/5.MAYO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTCruce("./altamira/2021/6.JUNIO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTCruce("./altamira/2021/7.JULIO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTCruce("./altamira/2021/8.AGOSTO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTCruce("./altamira/2021/9. SEPTIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTCruce("./altamira/2021/10. OCTUBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTCruce("./altamira/2021/11. NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTCruce("./altamira/2021/12. DICIEMBRE/ZONA CRUCE.xlsx", m, divisiones, minVariable, maxVariable)
#2022
m, minVariable, maxVariable = AlturaTCruce("./altamira/2022/1.ENERO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTCruce("./altamira/2022/2.FEBRERO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTCruce("./altamira/2022/3.MARZO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTCruce("./altamira/2022/4.ABRIL/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
#mayo 22 cruce vacío
m, minVariable, maxVariable = AlturaTCruce("./altamira/2022/8. AGOSTO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTCruce("./altamira/2022/6. JUNIO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTCruce("./altamira/2022/7.JULIO/ZONA CRUCE C.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTCruce("./altamira/2022/8. AGOSTO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTCruce("./altamira/2022/9. SEPTIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTCruce("./altamira/2022/10. OCTUBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTCruce("./altamira/2022/11. NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTCruce("./altamira/2022/12. DICIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)

# %% [markdown]
# ### Representar histogramas

# %%
def HistogramaTCruce(FicheroCruce, m, divisiones, MesAño, minVariable, maxVariable):
    '''
    Con atributos:
    1) Fichero Cruce: Fichero de datos de la sala
    2) m: La altura en el eje de ordenadas que se quiere representar
    3) divisiones: Número de intervalos en los que se quiere dividir el rango de datos de la variable
    4) MesAño: String indicando el mes y el año de los datos a representar
    5) minVariable: Minimo valor en el eje de abscisas a representar
    6) maxVariable: Minimo valor en el eje de abscisas a representar
    Se representa el histograma de la temperatura del Cruce por meses acotado según m, minVarible y 
    maxVariable.
    '''
    #Sacar el histograma
    df = pd.read_excel(FicheroCruce)
    bins = np.linspace(df["Temperatura D (° C)"].min(), df["Temperatura D (° C)"].max(), divisiones)
    np.histogram(df["Temperatura D (° C)"], bins=bins)
    plt.ylim(0, m)
    plt.xlim(minVariable,maxVariable)
    #Pintarlo+leyenda
    plt.grid()
    plt.hist(df["Temperatura D (° C)"], bins=divisiones, edgecolor='black')
    plt.title(MesAño)
    plt.xlabel("Temperatura Cruce / ºC")
    plt.ylabel("Frecuencia")
    plt.gca().set_axisbelow(True)
    plt.show()

# %%
#Prueba:
# HistogramaTCruce("./altamira/2020/10.OCTUBRE/ZONA CRUCE.xlsx", m, divisiones, 'Febrero 2022', minVariable, maxVariable)

# %%
# 2020
HistogramaTCruce("./altamira/2020/10.OCTUBRE/ZONA CRUCE.xlsx", m, divisiones, 'Octubre 2020', minVariable, maxVariable)
HistogramaTCruce("./altamira/2020/11.NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Noviembre 2020', minVariable, maxVariable)
HistogramaTCruce("./altamira/2020/12.DICIEMBRE/ZONA CRUCE.xlsx", m, divisiones, 'Diciembre 2020', minVariable, maxVariable)
#2021
HistogramaTCruce("./altamira/2021/1.ENERO/ZONA CRUCE ENERO.xlsx", m, divisiones, 'Enero 2021', minVariable, maxVariable)
HistogramaTCruce("./altamira/2021/2.FEBRERO/ZONA CRUCE D.xlsx", m, divisiones, 'Febrero 2021', minVariable, maxVariable)
HistogramaTCruce("./altamira/2021/3.MARZO/ZONA CRUCE D.xlsx", m, divisiones, 'Marzo 2021', minVariable, maxVariable)
HistogramaTCruce("./altamira/2021/4.ABRIL/ZONA CRUCE.xlsx", m, divisiones, 'Abril 2021', minVariable, maxVariable)
HistogramaTCruce("./altamira/2021/5.MAYO/ZONA CRUCE D.xlsx", m, divisiones, 'Mayo 2021', minVariable, maxVariable)
HistogramaTCruce("./altamira/2021/6.JUNIO/ZONA CRUCE D.xlsx", m, divisiones, 'Junio 2021', minVariable, maxVariable)
HistogramaTCruce("./altamira/2021/7.JULIO/ZONA CRUCE D.xlsx", m, divisiones, 'Julio 2021', minVariable, maxVariable)
HistogramaTCruce("./altamira/2021/8.AGOSTO/ZONA CRUCE D.xlsx", m, divisiones, 'Agosto 2021', minVariable, maxVariable)
HistogramaTCruce("./altamira/2021/9. SEPTIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Septiembre 2021', minVariable, maxVariable)
HistogramaTCruce("./altamira/2021/10. OCTUBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Octubre 2021', minVariable, maxVariable)
HistogramaTCruce("./altamira/2021/11. NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Noviembre 2021', minVariable, maxVariable)
HistogramaTCruce("./altamira/2021/12. DICIEMBRE/ZONA CRUCE.xlsx", m, divisiones, 'Diciembre 2021', minVariable, maxVariable)
#2022
HistogramaTCruce("./altamira/2022/1.ENERO/ZONA CRUCE D.xlsx", m, divisiones, 'Enero 2022', minVariable, maxVariable)
#'Temperatura D (° C)' son todo nans en febrero, marzo y abril del 22
# HistogramaTCruce("./altamira/2022/2.FEBRERO/ZONA CRUCE D.xlsx", m, divisiones, 'Febrero 2022', minVariable, maxVariable)
# HistogramaTCruce("./altamira/2022/3.MARZO/ZONA CRUCE D.xlsx", m, divisiones, 'Marzo 2022', minVariable, maxVariable)
# HistogramaTCruce("./altamira/2022/4.ABRIL/ZONA CRUCE D.xlsx", m, divisiones, 'Abril 2022', minVariable, maxVariable)
#mayo 22 cruce vacío
HistogramaTCruce("./altamira/2022/6. JUNIO/ZONA CRUCE D.xlsx", m, divisiones, 'Junio 2022', minVariable, maxVariable)
HistogramaTCruce("./altamira/2022/7.JULIO/ZONA CRUCE C.xlsx", m, divisiones, 'Julio 2022', minVariable, maxVariable)
HistogramaTCruce("./altamira/2022/8. AGOSTO/ZONA CRUCE D.xlsx", m, divisiones, 'Agosto 2022', minVariable, maxVariable)
HistogramaTCruce("./altamira/2022/9. SEPTIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Septiembre 2022', minVariable, maxVariable)
HistogramaTCruce("./altamira/2022/10. OCTUBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Octubre 2022', minVariable, maxVariable)
HistogramaTCruce("./altamira/2022/11. NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Noviembre 2022', minVariable, maxVariable)
HistogramaTCruce("./altamira/2022/12. DICIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Diciembre 2022', minVariable, maxVariable)

# %% [markdown]
# # 2. Histogramas de la temperatura de Cruce suavizada

# %% [markdown]
# ### Sacar el máximo de veces que se repite un dato en los histogramas:

# %%
m=0 #Máximo de datos por columna hasta este momento
minVariable=100000000000#Minimo  para comparar de la variable a representar
maxVariable=0#Máximo para comparar de la variable a representar
def AlturaTsuavCruce(FicheroCruce, m, divisiones, minVariable, maxVariable):
#     print('---------------------------------------------------------------')
    df = pd.read_excel(FicheroCruce)
    min_relativo=df['Tc_suavizada'].min()
    max_relativo=df['Tc_suavizada'].max()
    bins = np.linspace(min_relativo, max_relativo, divisiones)
    hist, bins = np.histogram(df['Tc_suavizada'], bins=bins)
#     print('Máximo de datos por columna hasta ahora:', m)
    for i in range(len(hist)):
#         print(f"Intervalo {i+1}: {hist[i]} datos")
        if hist[i]>m:
            m=hist[i]
    #Igualar la escala en x:
    if min_relativo<minVariable:
        minVariable=min_relativo
    if max_relativo>maxVariable:
        maxVariable=max_relativo
        
    return m, minVariable, maxVariable

# %%
# m, minVariable, maxVariable = AlturaTsuavCruce("./altamira/2020/10.OCTUBRE/ZONA CRUCE.xlsx", m, divisiones, minVariable, maxVariable)

# %%
# 2020
m, minVariable, maxVariable = AlturaTsuavCruce("./altamira/2020/10.OCTUBRE/ZONA CRUCE.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavCruce("./altamira/2020/11.NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavCruce("./altamira/2020/12.DICIEMBRE/ZONA CRUCE.xlsx", m, divisiones, minVariable, maxVariable)
#2021
m, minVariable, maxVariable = AlturaTsuavCruce("./altamira/2021/1.ENERO/ZONA CRUCE ENERO.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavCruce("./altamira/2021/2.FEBRERO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavCruce("./altamira/2021/3.MARZO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavCruce("./altamira/2021/4.ABRIL/ZONA CRUCE.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavCruce("./altamira/2021/5.MAYO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavCruce("./altamira/2021/6.JUNIO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavCruce("./altamira/2021/7.JULIO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavCruce("./altamira/2021/8.AGOSTO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavCruce("./altamira/2021/9. SEPTIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavCruce("./altamira/2021/10. OCTUBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavCruce("./altamira/2021/11. NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavCruce("./altamira/2021/12. DICIEMBRE/ZONA CRUCE.xlsx", m, divisiones, minVariable, maxVariable)
#2022
m, minVariable, maxVariable = AlturaTsuavCruce("./altamira/2022/1.ENERO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
# m = AlturaTsuavCruce("./altamira/2022/2.FEBRERO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
# m = AlturaTsuavCruce("./altamira/2022/3.MARZO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
# m = AlturaTsuavCruce("./altamira/2022/4.ABRIL/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
#mayo 22 cruce vacío
m, minVariable, maxVariable = AlturaTsuavCruce("./altamira/2022/8. AGOSTO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavCruce("./altamira/2022/6. JUNIO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavCruce("./altamira/2022/7.JULIO/ZONA CRUCE C.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavCruce("./altamira/2022/8. AGOSTO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavCruce("./altamira/2022/9. SEPTIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavCruce("./altamira/2022/10. OCTUBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavCruce("./altamira/2022/11. NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavCruce("./altamira/2022/12. DICIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)

# %% [markdown]
# ### Representar histogramas

# %%
def HistogramaTsuavCruce(FicheroCruce, m, divisiones, MesAño, minVariable, maxVariable):
    #Sacar el histograma
    df = pd.read_excel(FicheroCruce)
    bins = np.linspace(df['Tc_suavizada'].min(), df['Tc_suavizada'].max(), divisiones)
    np.histogram(df['Tc_suavizada'], bins=bins)
    plt.ylim(0, m)
    plt.xlim(minVariable,maxVariable)
    #Pintarlo+leyenda
    plt.grid()
    plt.hist(df['Tc_suavizada'], bins=divisiones, edgecolor='black')
    plt.title(MesAño)
    plt.xlabel("Temperatura Cruce suavizada / ºC")
    plt.ylabel("Frecuencia")
    plt.gca().set_axisbelow(True)
    plt.show()

# %%
# HistogramaTsuavCruce("./altamira/2020/10.OCTUBRE/ZONA CRUCE.xlsx", m, divisiones, 'Octubre 2020', minVariable, maxVariable)

# %%
# 2020
HistogramaTsuavCruce("./altamira/2020/10.OCTUBRE/ZONA CRUCE.xlsx", m, divisiones, 'Octubre 2020', minVariable, maxVariable)
HistogramaTsuavCruce("./altamira/2020/11.NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Noviembre 2020', minVariable, maxVariable)
HistogramaTsuavCruce("./altamira/2020/12.DICIEMBRE/ZONA CRUCE.xlsx", m, divisiones, 'Diciembre 2020', minVariable, maxVariable)
#2021
HistogramaTsuavCruce("./altamira/2021/1.ENERO/ZONA CRUCE ENERO.xlsx", m, divisiones, 'Enero 2021', minVariable, maxVariable)
HistogramaTsuavCruce("./altamira/2021/2.FEBRERO/ZONA CRUCE D.xlsx", m, divisiones, 'Febrero 2021', minVariable, maxVariable)
HistogramaTsuavCruce("./altamira/2021/3.MARZO/ZONA CRUCE D.xlsx", m, divisiones, 'Marzo 2021', minVariable, maxVariable)
HistogramaTsuavCruce("./altamira/2021/4.ABRIL/ZONA CRUCE.xlsx", m, divisiones, 'Abril 2021', minVariable, maxVariable)
HistogramaTsuavCruce("./altamira/2021/5.MAYO/ZONA CRUCE D.xlsx", m, divisiones, 'Mayo 2021', minVariable, maxVariable)
HistogramaTsuavCruce("./altamira/2021/6.JUNIO/ZONA CRUCE D.xlsx", m, divisiones, 'Junio 2021', minVariable, maxVariable)
HistogramaTsuavCruce("./altamira/2021/7.JULIO/ZONA CRUCE D.xlsx", m, divisiones, 'Julio 2021', minVariable, maxVariable)
HistogramaTsuavCruce("./altamira/2021/8.AGOSTO/ZONA CRUCE D.xlsx", m, divisiones, 'Agosto 2021', minVariable, maxVariable)
HistogramaTsuavCruce("./altamira/2021/9. SEPTIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Septiembre 2021', minVariable, maxVariable)
HistogramaTsuavCruce("./altamira/2021/10. OCTUBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Octubre 2021', minVariable, maxVariable)
HistogramaTsuavCruce("./altamira/2021/11. NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Noviembre 2021', minVariable, maxVariable)
HistogramaTsuavCruce("./altamira/2021/12. DICIEMBRE/ZONA CRUCE.xlsx", m, divisiones, 'Diciembre 2021', minVariable, maxVariable)
#2022
HistogramaTsuavCruce("./altamira/2022/1.ENERO/ZONA CRUCE D.xlsx", m, divisiones, 'Enero 2022', minVariable, maxVariable)
# HistogramaTsuavCruce("./altamira/2022/2.FEBRERO/ZONA CRUCE D.xlsx", m, divisiones, 'Febrero 2022', minVariable, maxVariable)
# HistogramaTsuavCruce("./altamira/2022/3.MARZO/ZONA CRUCE D.xlsx", m, divisiones, 'Marzo 2022', minVariable, maxVariable)
# HistogramaTsuavCruce("./altamira/2022/4.ABRIL/ZONA CRUCE D.xlsx", m, divisiones, 'Abril 2022', minVariable, maxVariable)
#mayo 22 cruce vacío
HistogramaTsuavCruce("./altamira/2022/6. JUNIO/ZONA CRUCE D.xlsx", m, divisiones, 'Junio 2022', minVariable, maxVariable)
HistogramaTsuavCruce("./altamira/2022/7.JULIO/ZONA CRUCE C.xlsx", m, divisiones, 'Julio 2022', minVariable, maxVariable)
HistogramaTsuavCruce("./altamira/2022/8. AGOSTO/ZONA CRUCE D.xlsx", m, divisiones, 'Agosto 2022', minVariable, maxVariable)
HistogramaTsuavCruce("./altamira/2022/9. SEPTIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Septiembre 2022', minVariable, maxVariable)
HistogramaTsuavCruce("./altamira/2022/10. OCTUBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Octubre 2022', minVariable, maxVariable)
HistogramaTsuavCruce("./altamira/2022/11. NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Noviembre 2022', minVariable, maxVariable)
HistogramaTsuavCruce("./altamira/2022/12. DICIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Diciembre 2022', minVariable, maxVariable)

# %% [markdown]
# # 3. Histogramas de la cantidad de CO2 de Cruce sin suavizar

# %% [markdown]
# ### Sacar el máximo de veces que se repite un dato en los histogramas:

# %%
m=0 #Máximo de datos por columna hasta este momento
minVariable=100000000000#Minimo  para comparar de la variable a representar
maxVariable=0#Máximo para comparar de la variable a representar
def AlturaCO2Cruce(FicheroCruce, m, divisiones, minVariable, maxVariable):
#     print('---------------------------------------------------------------')
    df = pd.read_excel(FicheroCruce)
    min_relativo=df['CO2 D (ppm)'].min()
    max_relativo=df['CO2 D (ppm)'].max()
    bins = np.linspace(min_relativo, max_relativo, divisiones)
    hist, bins = np.histogram(df['CO2 D (ppm)'], bins=bins)
#     print('Máximo de datos por columna hasta ahora:', m)
    for i in range(len(hist)):
#         print(f"Intervalo {i+1}: {hist[i]} datos")
        if hist[i]>m:
            m=hist[i]
    #Igualar la escala en x:
    if min_relativo<minVariable:
        minVariable=min_relativo
    if max_relativo>maxVariable:
        maxVariable=max_relativo
    return m, minVariable, maxVariable

# %%
# m, minVariable, maxVariable = AlturaCO2Cruce("./altamira/2020/10.OCTUBRE/ZONA CRUCE.xlsx", m, divisiones, minVariable, maxVariable)

# %%
# 2020
m, minVariable, maxVariable = AlturaCO2Cruce("./altamira/2020/10.OCTUBRE/ZONA CRUCE.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Cruce("./altamira/2020/11.NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Cruce("./altamira/2020/12.DICIEMBRE/ZONA CRUCE.xlsx", m, divisiones, minVariable, maxVariable)
#2021
m, minVariable, maxVariable = AlturaCO2Cruce("./altamira/2021/1.ENERO/ZONA CRUCE ENERO.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Cruce("./altamira/2021/2.FEBRERO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Cruce("./altamira/2021/3.MARZO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Cruce("./altamira/2021/4.ABRIL/ZONA CRUCE.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Cruce("./altamira/2021/5.MAYO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Cruce("./altamira/2021/6.JUNIO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Cruce("./altamira/2021/7.JULIO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Cruce("./altamira/2021/8.AGOSTO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Cruce("./altamira/2021/9. SEPTIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Cruce("./altamira/2021/10. OCTUBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Cruce("./altamira/2021/11. NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Cruce("./altamira/2021/12. DICIEMBRE/ZONA CRUCE.xlsx", m, divisiones, minVariable, maxVariable)
#2022
m, minVariable, maxVariable = AlturaCO2Cruce("./altamira/2022/1.ENERO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Cruce("./altamira/2022/2.FEBRERO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Cruce("./altamira/2022/3.MARZO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Cruce("./altamira/2022/4.ABRIL/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
#mayo 22 cruce vacío
m, minVariable, maxVariable = AlturaCO2Cruce("./altamira/2022/8. AGOSTO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Cruce("./altamira/2022/6. JUNIO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Cruce("./altamira/2022/7.JULIO/ZONA CRUCE C.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Cruce("./altamira/2022/8. AGOSTO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Cruce("./altamira/2022/9. SEPTIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Cruce("./altamira/2022/10. OCTUBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Cruce("./altamira/2022/11. NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Cruce("./altamira/2022/12. DICIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)

# %% [markdown]
# ### Representar histogramas

# %%
def HistogramaCO2Cruce(FicheroCruce, m, divisiones, MesAño, minVariable, maxVariable):
    #Sacar el histograma
    df = pd.read_excel(FicheroCruce)
    bins = np.linspace(df['CO2 D (ppm)'].min(), df['CO2 D (ppm)'].max(), divisiones)
    np.histogram(df['CO2 D (ppm)'], bins=bins)
    plt.ylim(0, m)
    plt.xlim(minVariable,maxVariable)
    #Pintarlo+leyenda
    plt.grid()
    plt.hist(df['CO2 D (ppm)'], bins=divisiones, edgecolor='black')
    plt.title(MesAño)
    plt.xlabel("CO2 Cruce / ºC")
    plt.ylabel("Frecuencia")
    plt.gca().set_axisbelow(True)
    plt.show()

# %%
# HistogramaCO2Cruce("./altamira/2020/10.OCTUBRE/ZONA CRUCE.xlsx", m, divisiones, 'Octubre 2020', minVariable, maxVariable)

# %%
# 2020
HistogramaCO2Cruce("./altamira/2020/10.OCTUBRE/ZONA CRUCE.xlsx", m, divisiones, 'Octubre 2020', minVariable, maxVariable)
HistogramaCO2Cruce("./altamira/2020/11.NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Noviembre 2020', minVariable, maxVariable)
HistogramaCO2Cruce("./altamira/2020/12.DICIEMBRE/ZONA CRUCE.xlsx", m, divisiones, 'Diciembre 2020', minVariable, maxVariable)
#2021
HistogramaCO2Cruce("./altamira/2021/1.ENERO/ZONA CRUCE ENERO.xlsx", m, divisiones, 'Enero 2021', minVariable, maxVariable)
HistogramaCO2Cruce("./altamira/2021/2.FEBRERO/ZONA CRUCE D.xlsx", m, divisiones, 'Febrero 2021', minVariable, maxVariable)
HistogramaCO2Cruce("./altamira/2021/3.MARZO/ZONA CRUCE D.xlsx", m, divisiones, 'Marzo 2021', minVariable, maxVariable)
HistogramaCO2Cruce("./altamira/2021/4.ABRIL/ZONA CRUCE.xlsx", m, divisiones, 'Abril 2021', minVariable, maxVariable)
HistogramaCO2Cruce("./altamira/2021/5.MAYO/ZONA CRUCE D.xlsx", m, divisiones, 'Mayo 2021', minVariable, maxVariable)
HistogramaCO2Cruce("./altamira/2021/6.JUNIO/ZONA CRUCE D.xlsx", m, divisiones, 'Junio 2021', minVariable, maxVariable)
HistogramaCO2Cruce("./altamira/2021/7.JULIO/ZONA CRUCE D.xlsx", m, divisiones, 'Julio 2021', minVariable, maxVariable)
HistogramaCO2Cruce("./altamira/2021/8.AGOSTO/ZONA CRUCE D.xlsx", m, divisiones, 'Agosto 2021', minVariable, maxVariable)
HistogramaCO2Cruce("./altamira/2021/9. SEPTIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Septiembre 2021', minVariable, maxVariable)
HistogramaCO2Cruce("./altamira/2021/10. OCTUBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Octubre 2021', minVariable, maxVariable)
HistogramaCO2Cruce("./altamira/2021/11. NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Noviembre 2021', minVariable, maxVariable)
HistogramaCO2Cruce("./altamira/2021/12. DICIEMBRE/ZONA CRUCE.xlsx", m, divisiones, 'Diciembre 2021', minVariable, maxVariable)
#2022
HistogramaCO2Cruce("./altamira/2022/1.ENERO/ZONA CRUCE D.xlsx", m, divisiones, 'Enero 2022', minVariable, maxVariable)
HistogramaCO2Cruce("./altamira/2022/2.FEBRERO/ZONA CRUCE D.xlsx", m, divisiones, 'Febrero 2022', minVariable, maxVariable)
HistogramaCO2Cruce("./altamira/2022/3.MARZO/ZONA CRUCE D.xlsx", m, divisiones, 'Marzo 2022', minVariable, maxVariable)
HistogramaCO2Cruce("./altamira/2022/4.ABRIL/ZONA CRUCE D.xlsx", m, divisiones, 'Abril 2022', minVariable, maxVariable)
#mayo 22 cruce vacío
HistogramaCO2Cruce("./altamira/2022/6. JUNIO/ZONA CRUCE D.xlsx", m, divisiones, 'Junio 2022', minVariable, maxVariable)
HistogramaCO2Cruce("./altamira/2022/7.JULIO/ZONA CRUCE C.xlsx", m, divisiones, 'Julio 2022', minVariable, maxVariable)
HistogramaCO2Cruce("./altamira/2022/8. AGOSTO/ZONA CRUCE D.xlsx", m, divisiones, 'Agosto 2022', minVariable, maxVariable)
HistogramaCO2Cruce("./altamira/2022/9. SEPTIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Septiembre 2022', minVariable, maxVariable)
HistogramaCO2Cruce("./altamira/2022/10. OCTUBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Octubre 2022', minVariable, maxVariable)
HistogramaCO2Cruce("./altamira/2022/11. NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Noviembre 2022', minVariable, maxVariable)
HistogramaCO2Cruce("./altamira/2022/12. DICIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Diciembre 2022', minVariable, maxVariable)

# %% [markdown]
# # 4. Histogramas de la cantidad de CO2 de Cruce suavizada

# %% [markdown]
# ### Sacar el máximo de veces que se repite un dato en los histogramas:

# %%
m=0 #Máximo de datos por columna hasta este momento
minVariable=100000000000#Minimo  para comparar de la variable a representar
maxVariable=0#Máximo para comparar de la variable a representar
def AlturaCO2suavCruce(FicheroCruce, m, divisiones, minVariable, maxVariable):
#     print('---------------------------------------------------------------')
    df = pd.read_excel(FicheroCruce)
    min_relativo=df['CO2c_suavizado'].min()
    max_relativo=df['CO2c_suavizado'].max()
    bins = np.linspace(min_relativo, max_relativo, divisiones)
    hist, bins = np.histogram(df['CO2c_suavizado'], bins=bins)
#     print('Máximo de datos por columna hasta ahora:', m)
    for i in range(len(hist)):
#         print(f"Intervalo {i+1}: {hist[i]} datos")
        if hist[i]>m:
            m=hist[i]
    #Igualar la escala en x:
    if min_relativo<minVariable:
        minVariable=min_relativo
    if max_relativo>maxVariable:
        maxVariable=max_relativo
    return m, minVariable, maxVariable

# %%
# m, minVariable, maxVariable = AlturaCO2suavCruce("./altamira/2020/10.OCTUBRE/ZONA CRUCE.xlsx", m, divisiones, minVariable, maxVariable)

# %%
# 2020
m, minVariable, maxVariable = AlturaCO2suavCruce("./altamira/2020/10.OCTUBRE/ZONA CRUCE.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavCruce("./altamira/2020/11.NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavCruce("./altamira/2020/12.DICIEMBRE/ZONA CRUCE.xlsx", m, divisiones, minVariable, maxVariable)
#2021
m, minVariable, maxVariable = AlturaCO2suavCruce("./altamira/2021/1.ENERO/ZONA CRUCE ENERO.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavCruce("./altamira/2021/2.FEBRERO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavCruce("./altamira/2021/3.MARZO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavCruce("./altamira/2021/4.ABRIL/ZONA CRUCE.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavCruce("./altamira/2021/5.MAYO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavCruce("./altamira/2021/6.JUNIO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavCruce("./altamira/2021/7.JULIO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavCruce("./altamira/2021/8.AGOSTO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavCruce("./altamira/2021/9. SEPTIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavCruce("./altamira/2021/10. OCTUBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavCruce("./altamira/2021/11. NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavCruce("./altamira/2021/12. DICIEMBRE/ZONA CRUCE.xlsx", m, divisiones, minVariable, maxVariable)
#2022
m, minVariable, maxVariable = AlturaCO2suavCruce("./altamira/2022/1.ENERO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavCruce("./altamira/2022/2.FEBRERO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavCruce("./altamira/2022/3.MARZO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavCruce("./altamira/2022/4.ABRIL/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
#mayo 22 cruce vacío
m, minVariable, maxVariable = AlturaCO2suavCruce("./altamira/2022/8. AGOSTO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavCruce("./altamira/2022/6. JUNIO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavCruce("./altamira/2022/7.JULIO/ZONA CRUCE C.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavCruce("./altamira/2022/8. AGOSTO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavCruce("./altamira/2022/9. SEPTIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavCruce("./altamira/2022/10. OCTUBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavCruce("./altamira/2022/11. NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavCruce("./altamira/2022/12. DICIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)

# %% [markdown]
# ### Representar histogramas

# %%
def HistogramaCO2suavCruce(FicheroCruce, m, divisiones, MesAño, minVariable, maxVariable):
    #Sacar el histograma
    df = pd.read_excel(FicheroCruce)
    bins = np.linspace(df['CO2c_suavizado'].min(), df['CO2c_suavizado'].max(), divisiones)
    np.histogram(df['CO2c_suavizado'], bins=bins)
    plt.ylim(0, m)
    plt.xlim(minVariable,maxVariable)
    #Pintarlo+leyenda
    plt.grid()
    plt.hist(df['CO2c_suavizado'], bins=divisiones, edgecolor='black')
    plt.title(MesAño)
    plt.xlabel("CO2 suavizado Cruce / ºC")
    plt.ylabel("Frecuencia")
    plt.gca().set_axisbelow(True)
    plt.show()

# %%
# HistogramaCO2suavCruce("./altamira/2020/10.OCTUBRE/ZONA CRUCE.xlsx", m, divisiones, 'Octubre 2020', minVariable, maxVariable)

# %%
# 2020
HistogramaCO2suavCruce("./altamira/2020/10.OCTUBRE/ZONA CRUCE.xlsx", m, divisiones, 'Octubre 2020', minVariable, maxVariable)
HistogramaCO2suavCruce("./altamira/2020/11.NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Noviembre 2020', minVariable, maxVariable)
HistogramaCO2suavCruce("./altamira/2020/12.DICIEMBRE/ZONA CRUCE.xlsx", m, divisiones, 'Diciembre 2020', minVariable, maxVariable)
#2021
HistogramaCO2suavCruce("./altamira/2021/1.ENERO/ZONA CRUCE ENERO.xlsx", m, divisiones, 'Enero 2021', minVariable, maxVariable)
HistogramaCO2suavCruce("./altamira/2021/2.FEBRERO/ZONA CRUCE D.xlsx", m, divisiones, 'Febrero 2021', minVariable, maxVariable)
HistogramaCO2suavCruce("./altamira/2021/3.MARZO/ZONA CRUCE D.xlsx", m, divisiones, 'Marzo 2021', minVariable, maxVariable)
HistogramaCO2suavCruce("./altamira/2021/4.ABRIL/ZONA CRUCE.xlsx", m, divisiones, 'Abril 2021', minVariable, maxVariable)
HistogramaCO2suavCruce("./altamira/2021/5.MAYO/ZONA CRUCE D.xlsx", m, divisiones, 'Mayo 2021', minVariable, maxVariable)
HistogramaCO2suavCruce("./altamira/2021/6.JUNIO/ZONA CRUCE D.xlsx", m, divisiones, 'Junio 2021', minVariable, maxVariable)
HistogramaCO2suavCruce("./altamira/2021/7.JULIO/ZONA CRUCE D.xlsx", m, divisiones, 'Julio 2021', minVariable, maxVariable)
HistogramaCO2suavCruce("./altamira/2021/8.AGOSTO/ZONA CRUCE D.xlsx", m, divisiones, 'Agosto 2021', minVariable, maxVariable)
HistogramaCO2suavCruce("./altamira/2021/9. SEPTIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Septiembre 2021', minVariable, maxVariable)
HistogramaCO2suavCruce("./altamira/2021/10. OCTUBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Octubre 2021', minVariable, maxVariable)
HistogramaCO2suavCruce("./altamira/2021/11. NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Noviembre 2021', minVariable, maxVariable)
HistogramaCO2suavCruce("./altamira/2021/12. DICIEMBRE/ZONA CRUCE.xlsx", m, divisiones, 'Diciembre 2021', minVariable, maxVariable)
#2022
HistogramaCO2suavCruce("./altamira/2022/1.ENERO/ZONA CRUCE D.xlsx", m, divisiones, 'Enero 2022', minVariable, maxVariable)
HistogramaCO2suavCruce("./altamira/2022/2.FEBRERO/ZONA CRUCE D.xlsx", m, divisiones, 'Febrero 2022', minVariable, maxVariable)
HistogramaCO2suavCruce("./altamira/2022/3.MARZO/ZONA CRUCE D.xlsx", m, divisiones, 'Marzo 2022', minVariable, maxVariable)
HistogramaCO2suavCruce("./altamira/2022/4.ABRIL/ZONA CRUCE D.xlsx", m, divisiones, 'Abril 2022', minVariable, maxVariable)
#mayo 22 cruce vacío
HistogramaCO2suavCruce("./altamira/2022/6. JUNIO/ZONA CRUCE D.xlsx", m, divisiones, 'Junio 2022', minVariable, maxVariable)
HistogramaCO2suavCruce("./altamira/2022/7.JULIO/ZONA CRUCE C.xlsx", m, divisiones, 'Julio 2022', minVariable, maxVariable)
HistogramaCO2suavCruce("./altamira/2022/8. AGOSTO/ZONA CRUCE D.xlsx", m, divisiones, 'Agosto 2022', minVariable, maxVariable)
HistogramaCO2suavCruce("./altamira/2022/9. SEPTIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Septiembre 2022', minVariable, maxVariable)
HistogramaCO2suavCruce("./altamira/2022/10. OCTUBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Octubre 2022', minVariable, maxVariable)
HistogramaCO2suavCruce("./altamira/2022/11. NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Noviembre 2022', minVariable, maxVariable)
HistogramaCO2suavCruce("./altamira/2022/12. DICIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Diciembre 2022', minVariable, maxVariable)

# %% [markdown]
# # 5. Histogramas de la temperatura del Ramal sin suavizar

# %% [markdown]
# ### Sacar el máximo de veces que se repite un dato en los histogramas:

# %%
m=0 #Máximo de datos por columna hasta este momento
minVariable=100000000000#Minimo  para comparar de la variable a representar
maxVariable=0#Máximo para comparar de la variable a representar
def AlturaTRamalCruce(FicheroCruce, m, divisiones, minVariable, maxVariable):
#     print('---------------------------------------------------------------')
    df = pd.read_excel(FicheroCruce)
    min_relativo=df["tr Cruce Ramal ('C)"].min()
    max_relativo=df["tr Cruce Ramal ('C)"].max()
    bins = np.linspace(min_relativo, max_relativo, divisiones)
    hist, bins = np.histogram(df["tr Cruce Ramal ('C)"], bins=bins)
#     print('Máximo de datos por columna hasta ahora:', m)
    for i in range(len(hist)):
#         print(f"Intervalo {i+1}: {hist[i]} datos")
        if hist[i]>m:
            m=hist[i]
    #Igualar la escala en x:
    if min_relativo<minVariable:
        minVariable=min_relativo
    if max_relativo>maxVariable:
        maxVariable=max_relativo
    return m, minVariable, maxVariable

# %%
# m, minVariable, maxVariable = AlturaTRamalCruce("./altamira/2020/10.OCTUBRE/ZONA CRUCE.xlsx", m, divisiones, minVariable, maxVariable)

# %%
# 2020
m, minVariable, maxVariable= AlturaTRamalCruce("./altamira/2020/10.OCTUBRE/ZONA CRUCE.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalCruce("./altamira/2020/11.NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalCruce("./altamira/2020/12.DICIEMBRE/ZONA CRUCE.xlsx", m, divisiones, minVariable, maxVariable)
#2021
m, minVariable, maxVariable = AlturaTRamalCruce("./altamira/2021/1.ENERO/ZONA CRUCE ENERO.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalCruce("./altamira/2021/2.FEBRERO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalCruce("./altamira/2021/3.MARZO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalCruce("./altamira/2021/4.ABRIL/ZONA CRUCE.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalCruce("./altamira/2021/5.MAYO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalCruce("./altamira/2021/6.JUNIO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalCruce("./altamira/2021/7.JULIO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalCruce("./altamira/2021/8.AGOSTO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalCruce("./altamira/2021/9. SEPTIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalCruce("./altamira/2021/10. OCTUBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalCruce("./altamira/2021/11. NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalCruce("./altamira/2021/12. DICIEMBRE/ZONA CRUCE.xlsx", m, divisiones, minVariable, maxVariable)
#2022
m, minVariable, maxVariable = AlturaTRamalCruce("./altamira/2022/1.ENERO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalCruce("./altamira/2022/2.FEBRERO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalCruce("./altamira/2022/3.MARZO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalCruce("./altamira/2022/4.ABRIL/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
#mayo 22 cruce vacío
m, minVariable, maxVariable = AlturaTRamalCruce("./altamira/2022/8. AGOSTO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalCruce("./altamira/2022/6. JUNIO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalCruce("./altamira/2022/7.JULIO/ZONA CRUCE C.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalCruce("./altamira/2022/8. AGOSTO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalCruce("./altamira/2022/9. SEPTIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalCruce("./altamira/2022/10. OCTUBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalCruce("./altamira/2022/11. NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalCruce("./altamira/2022/12. DICIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)

# %% [markdown]
# ### Representar histogramas

# %%
def HistogramaTRamalCruce(FicheroCruce, m, divisiones, MesAño, minVariable, maxVariable):
    #Sacar el histograma
    df = pd.read_excel(FicheroCruce)
    bins = np.linspace(df["tr Cruce Ramal ('C)"].min(), df["tr Cruce Ramal ('C)"].max(), divisiones)
    np.histogram(df["tr Cruce Ramal ('C)"], bins=bins)
    plt.ylim(0, m)
    plt.xlim(minVariable,maxVariable)
    #Pintarlo+leyenda
    plt.grid()
    plt.hist(df["tr Cruce Ramal ('C)"], bins=divisiones, edgecolor='black')
    plt.title(MesAño)
    plt.xlabel("Temperatura Ramal / ºC")
    plt.ylabel("Frecuencia")
    plt.gca().set_axisbelow(True)
    plt.show()

# %%
# HistogramaTRamalCruce("./altamira/2020/10.OCTUBRE/ZONA CRUCE.xlsx", m, divisiones, 'Octubre 2020', minVariable, maxVariable)

# %%
# 2020
HistogramaTRamalCruce("./altamira/2020/10.OCTUBRE/ZONA CRUCE.xlsx", m, divisiones, 'Octubre 2020', minVariable, maxVariable)
HistogramaTRamalCruce("./altamira/2020/11.NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Noviembre 2020', minVariable, maxVariable)
HistogramaTRamalCruce("./altamira/2020/12.DICIEMBRE/ZONA CRUCE.xlsx", m, divisiones, 'Diciembre 2020', minVariable, maxVariable)
#2021
HistogramaTRamalCruce("./altamira/2021/1.ENERO/ZONA CRUCE ENERO.xlsx", m, divisiones, 'Enero 2021', minVariable, maxVariable)
HistogramaTRamalCruce("./altamira/2021/2.FEBRERO/ZONA CRUCE D.xlsx", m, divisiones, 'Febrero 2021', minVariable, maxVariable)
HistogramaTRamalCruce("./altamira/2021/3.MARZO/ZONA CRUCE D.xlsx", m, divisiones, 'Marzo 2021', minVariable, maxVariable)
HistogramaTRamalCruce("./altamira/2021/4.ABRIL/ZONA CRUCE.xlsx", m, divisiones, 'Abril 2021', minVariable, maxVariable)
HistogramaTRamalCruce("./altamira/2021/5.MAYO/ZONA CRUCE D.xlsx", m, divisiones, 'Mayo 2021', minVariable, maxVariable)
HistogramaTRamalCruce("./altamira/2021/6.JUNIO/ZONA CRUCE D.xlsx", m, divisiones, 'Junio 2021', minVariable, maxVariable)
HistogramaTRamalCruce("./altamira/2021/7.JULIO/ZONA CRUCE D.xlsx", m, divisiones, 'Julio 2021', minVariable, maxVariable)
HistogramaTRamalCruce("./altamira/2021/8.AGOSTO/ZONA CRUCE D.xlsx", m, divisiones, 'Agosto 2021', minVariable, maxVariable)
HistogramaTRamalCruce("./altamira/2021/9. SEPTIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Septiembre 2021', minVariable, maxVariable)
HistogramaTRamalCruce("./altamira/2021/10. OCTUBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Octubre 2021', minVariable, maxVariable)
HistogramaTRamalCruce("./altamira/2021/11. NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Noviembre 2021', minVariable, maxVariable)
HistogramaTRamalCruce("./altamira/2021/12. DICIEMBRE/ZONA CRUCE.xlsx", m, divisiones, 'Diciembre 2021', minVariable, maxVariable)
#2022
HistogramaTRamalCruce("./altamira/2022/1.ENERO/ZONA CRUCE D.xlsx", m, divisiones, 'Enero 2022', minVariable, maxVariable)
HistogramaTRamalCruce("./altamira/2022/2.FEBRERO/ZONA CRUCE D.xlsx", m, divisiones, 'Febrero 2022', minVariable, maxVariable)
HistogramaTRamalCruce("./altamira/2022/3.MARZO/ZONA CRUCE D.xlsx", m, divisiones, 'Marzo 2022', minVariable, maxVariable)
HistogramaTRamalCruce("./altamira/2022/4.ABRIL/ZONA CRUCE D.xlsx", m, divisiones, 'Abril 2022', minVariable, maxVariable)
#mayo 22 cruce vacío
HistogramaTRamalCruce("./altamira/2022/6. JUNIO/ZONA CRUCE D.xlsx", m, divisiones, 'Junio 2022', minVariable, maxVariable)
HistogramaTRamalCruce("./altamira/2022/7.JULIO/ZONA CRUCE C.xlsx", m, divisiones, 'Julio 2022', minVariable, maxVariable)
HistogramaTRamalCruce("./altamira/2022/8. AGOSTO/ZONA CRUCE D.xlsx", m, divisiones, 'Agosto 2022', minVariable, maxVariable)
HistogramaTRamalCruce("./altamira/2022/9. SEPTIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Septiembre 2022', minVariable, maxVariable)
HistogramaTRamalCruce("./altamira/2022/10. OCTUBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Octubre 2022', minVariable, maxVariable)
HistogramaTRamalCruce("./altamira/2022/11. NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Noviembre 2022', minVariable, maxVariable)
HistogramaTRamalCruce("./altamira/2022/12. DICIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Diciembre 2022', minVariable, maxVariable)

# %% [markdown]
# # 6. Histogramas de la temperatura del Ramal suavizada

# %% [markdown]
# ### Sacar el máximo de veces que se repite un dato en los histogramas:

# %%
m=0 #Máximo de datos por columna hasta este momento
minVariable=100000000000#Minimo  para comparar de la variable a representar
maxVariable=0#Máximo para comparar de la variable a representar
def AlturaTRamalsuavCruce(FicheroCruce, m, divisiones, minVariable, maxVariable):
#     print('---------------------------------------------------------------')
    df = pd.read_excel(FicheroCruce)
    min_relativo=df['Tr_suavizada'].min()
    max_relativo=df['Tr_suavizada'].max()
    bins = np.linspace(min_relativo, max_relativo, divisiones)
    hist, bins = np.histogram(df['Tr_suavizada'], bins=bins)
#     print('Máximo de datos por columna hasta ahora:', m)
    for i in range(len(hist)):
#         print(f"Intervalo {i+1}: {hist[i]} datos")
        if hist[i]>m:
            m=hist[i]
    #Igualar la escala en x:
    if min_relativo<minVariable:
        minVariable=min_relativo
    if max_relativo>maxVariable:
        maxVariable=max_relativo
    return m, minVariable, maxVariable

# %%
# m, minVariable, maxVariable = AlturaTRamalsuavCruce("./altamira/2020/10.OCTUBRE/ZONA CRUCE.xlsx", m, divisiones, minVariable, maxVariable)

# %%
# 2020
m, minVariable, maxVariable = AlturaTRamalsuavCruce("./altamira/2020/10.OCTUBRE/ZONA CRUCE.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalsuavCruce("./altamira/2020/11.NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalsuavCruce("./altamira/2020/12.DICIEMBRE/ZONA CRUCE.xlsx", m, divisiones, minVariable, maxVariable)
#2021
m, minVariable, maxVariable = AlturaTRamalsuavCruce("./altamira/2021/1.ENERO/ZONA CRUCE ENERO.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalsuavCruce("./altamira/2021/2.FEBRERO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalsuavCruce("./altamira/2021/3.MARZO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalsuavCruce("./altamira/2021/4.ABRIL/ZONA CRUCE.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalsuavCruce("./altamira/2021/5.MAYO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalsuavCruce("./altamira/2021/6.JUNIO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalsuavCruce("./altamira/2021/7.JULIO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalsuavCruce("./altamira/2021/8.AGOSTO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalsuavCruce("./altamira/2021/9. SEPTIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalsuavCruce("./altamira/2021/10. OCTUBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalsuavCruce("./altamira/2021/11. NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalsuavCruce("./altamira/2021/12. DICIEMBRE/ZONA CRUCE.xlsx", m, divisiones, minVariable, maxVariable)
#2022
m, minVariable, maxVariable = AlturaTRamalsuavCruce("./altamira/2022/1.ENERO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalsuavCruce("./altamira/2022/2.FEBRERO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalsuavCruce("./altamira/2022/3.MARZO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalsuavCruce("./altamira/2022/4.ABRIL/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
#mayo 22 cruce vacío
m, minVariable, maxVariable = AlturaTRamalsuavCruce("./altamira/2022/8. AGOSTO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalsuavCruce("./altamira/2022/6. JUNIO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalsuavCruce("./altamira/2022/7.JULIO/ZONA CRUCE C.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalsuavCruce("./altamira/2022/8. AGOSTO/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalsuavCruce("./altamira/2022/9. SEPTIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalsuavCruce("./altamira/2022/10. OCTUBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalsuavCruce("./altamira/2022/11. NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTRamalsuavCruce("./altamira/2022/12. DICIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, minVariable, maxVariable)

# %% [markdown]
# ### Representar histogramas

# %%
def HistogramaTRamalsuavCruce(FicheroCruce, m, divisiones, MesAño, minVariable, maxVariable):
    #Sacar el histograma
    df = pd.read_excel(FicheroCruce)
    bins = np.linspace(df['Tr_suavizada'].min(), df['Tr_suavizada'].max(), divisiones)
    np.histogram(df['Tr_suavizada'], bins=bins)
    plt.ylim(0, m)
    plt.xlim(minVariable,maxVariable)
    #Pintarlo+leyenda
    plt.grid()
    plt.hist(df['Tr_suavizada'], bins=divisiones, edgecolor='black')
    plt.title(MesAño)
    plt.xlabel("Temperatura suavizada Ramal / ºC")
    plt.ylabel("Frecuencia")
    plt.gca().set_axisbelow(True)
    plt.show()

# %%
# HistogramaTRamalsuavCruce("./altamira/2020/10.OCTUBRE/ZONA CRUCE.xlsx", m, divisiones, 'Octubre 2020', minVariable, maxVariable)

# %%
# 2020
HistogramaTRamalsuavCruce("./altamira/2020/10.OCTUBRE/ZONA CRUCE.xlsx", m, divisiones, 'Octubre 2020', minVariable, maxVariable)
HistogramaTRamalsuavCruce("./altamira/2020/11.NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Noviembre 2020', minVariable, maxVariable)
HistogramaTRamalsuavCruce("./altamira/2020/12.DICIEMBRE/ZONA CRUCE.xlsx", m, divisiones, 'Diciembre 2020', minVariable, maxVariable)
#2021
HistogramaTRamalsuavCruce("./altamira/2021/1.ENERO/ZONA CRUCE ENERO.xlsx", m, divisiones, 'Enero 2021', minVariable, maxVariable)
HistogramaTRamalsuavCruce("./altamira/2021/2.FEBRERO/ZONA CRUCE D.xlsx", m, divisiones, 'Febrero 2021', minVariable, maxVariable)
HistogramaTRamalsuavCruce("./altamira/2021/3.MARZO/ZONA CRUCE D.xlsx", m, divisiones, 'Marzo 2021', minVariable, maxVariable)
HistogramaTRamalsuavCruce("./altamira/2021/4.ABRIL/ZONA CRUCE.xlsx", m, divisiones, 'Abril 2021', minVariable, maxVariable)
HistogramaTRamalsuavCruce("./altamira/2021/5.MAYO/ZONA CRUCE D.xlsx", m, divisiones, 'Mayo 2021', minVariable, maxVariable)
HistogramaTRamalsuavCruce("./altamira/2021/6.JUNIO/ZONA CRUCE D.xlsx", m, divisiones, 'Junio 2021', minVariable, maxVariable)
HistogramaTRamalsuavCruce("./altamira/2021/7.JULIO/ZONA CRUCE D.xlsx", m, divisiones, 'Julio 2021', minVariable, maxVariable)
HistogramaTRamalsuavCruce("./altamira/2021/8.AGOSTO/ZONA CRUCE D.xlsx", m, divisiones, 'Agosto 2021', minVariable, maxVariable)
HistogramaTRamalsuavCruce("./altamira/2021/9. SEPTIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Septiembre 2021', minVariable, maxVariable)
HistogramaTRamalsuavCruce("./altamira/2021/10. OCTUBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Octubre 2021', minVariable, maxVariable)
HistogramaTRamalsuavCruce("./altamira/2021/11. NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Noviembre 2021', minVariable, maxVariable)
HistogramaTRamalsuavCruce("./altamira/2021/12. DICIEMBRE/ZONA CRUCE.xlsx", m, divisiones, 'Diciembre 2021', minVariable, maxVariable)
#2022
HistogramaTRamalsuavCruce("./altamira/2022/1.ENERO/ZONA CRUCE D.xlsx", m, divisiones, 'Enero 2022', minVariable, maxVariable)
HistogramaTRamalsuavCruce("./altamira/2022/2.FEBRERO/ZONA CRUCE D.xlsx", m, divisiones, 'Febrero 2022', minVariable, maxVariable)
HistogramaTRamalsuavCruce("./altamira/2022/3.MARZO/ZONA CRUCE D.xlsx", m, divisiones, 'Marzo 2022', minVariable, maxVariable)
HistogramaTRamalsuavCruce("./altamira/2022/4.ABRIL/ZONA CRUCE D.xlsx", m, divisiones, 'Abril 2022', minVariable, maxVariable)
#mayo 22 cruce vacío
HistogramaTRamalsuavCruce("./altamira/2022/6. JUNIO/ZONA CRUCE D.xlsx", m, divisiones, 'Junio 2022', minVariable, maxVariable)
HistogramaTRamalsuavCruce("./altamira/2022/7.JULIO/ZONA CRUCE C.xlsx", m, divisiones, 'Julio 2022', minVariable, maxVariable)
HistogramaTRamalsuavCruce("./altamira/2022/8. AGOSTO/ZONA CRUCE D.xlsx", m, divisiones, 'Agosto 2022', minVariable, maxVariable)
HistogramaTRamalsuavCruce("./altamira/2022/9. SEPTIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Septiembre 2022', minVariable, maxVariable)
HistogramaTRamalsuavCruce("./altamira/2022/10. OCTUBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Octubre 2022', minVariable, maxVariable)
HistogramaTRamalsuavCruce("./altamira/2022/11. NOVIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Noviembre 2022', minVariable, maxVariable)
HistogramaTRamalsuavCruce("./altamira/2022/12. DICIEMBRE/ZONA CRUCE D.xlsx", m, divisiones, 'Diciembre 2022', minVariable, maxVariable)
