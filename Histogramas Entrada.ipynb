# %% [markdown]
# ### Histogramas Entrada:
# Contenido del fichero:
# 1. Histogramas de la temperatura de Entrada sin suavizar
# 2. Histogramas de la temperatura de Entrada suavizada
# 3. Histogramas de la cantidad de CO2 de Entrada sin suavizar
# 4. Histogramas de la cantidad de CO2 de Entrada suavizada

# %%
# Imports:
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Variables que se pueden modificar:
divisiones = 10 #Numero de intervalos en los que se dividen los datos a representar en el histograma

# %% [markdown]
# # 1. Histogramas de la temperatura de Entrada sin suavizar

# %% [markdown]
# ### Sacar el máximo de veces que se repite un dato en los histogramas:

# %%
m=0 #Máximo de datos por columna hasta este momento
minVariable=100000000000#Minimo  para comparar de la variable a representar
maxVariable=0#Máximo para comparar de la variable a representar
def AlturaTEntrada(FicheroEntrada, m, divisiones, minVariable, maxVariable):
#     print('---------------------------------------------------------------')
    df = pd.read_excel(FicheroEntrada)
    min_relativo=df['Temperatura A (° C)'].min()
    max_relativo=df['Temperatura A (° C)'].max()
    bins = np.linspace(min_relativo, max_relativo, divisiones)
    hist, bins = np.histogram(df['Temperatura A (° C)'], bins=bins)
#     print('Máximo de datos por columna hasta ahora:', m)
    for i in range(len(hist)):
#         print(f"Intervalo {i+1}: {hist[i]} datos")
        if hist[i]>m:
            m=hist[i]
    #Igualar la escala en x:
    if min_relativo<minVariable:
        minVariable=min_relativo
    if max_relativo>maxVariable:
        maxVariable=max_relativo
    return m, minVariable, maxVariable

# %%
# m, minVariable, maxVariable=AlturaTEntrada("./altamira/2020/10.OCTUBRE/ZONA ENTRADA.xlsx", m, divisiones, minVariable, maxVariable)

# %%
2020
m, minVariable, maxVariable = AlturaTEntrada("./altamira/2020/10.OCTUBRE/ZONA ENTRADA.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTEntrada("./altamira/2020/11.NOVIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTEntrada("./altamira/2020/12.DICIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
#2021
m, minVariable, maxVariable = AlturaTEntrada("./altamira/2021/1.ENERO/ZONA ENTRADA ENERO.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTEntrada("./altamira/2021/2.FEBRERO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTEntrada("./altamira/2021/3.MARZO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTEntrada("./altamira/2021/4.ABRIL/ZONA ENTRADA.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTEntrada("./altamira/2021/5.MAYO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTEntrada("./altamira/2021/6.JUNIO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTEntrada("./altamira/2021/7.JULIO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTEntrada("./altamira/2021/8.AGOSTO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTEntrada("./altamira/2021/9. SEPTIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTEntrada("./altamira/2021/10. OCTUBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTEntrada("./altamira/2021/11. NOVIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTEntrada("./altamira/2021/12. DICIEMBRE/ZONA ENTRADA.xlsx", m, divisiones, minVariable, maxVariable)
#2022
m, minVariable, maxVariable = AlturaTEntrada("./altamira/2022/1.ENERO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTEntrada("./altamira/2022/2.FEBRERO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTEntrada("./altamira/2022/3.MARZO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTEntrada("./altamira/2022/4.ABRIL/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTEntrada("./altamira/2022/5.MAYO/ZONA ENTRADA.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTEntrada("./altamira/2022/6. JUNIO/ZONA ENTRADA.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTEntrada("./altamira/2022/7.JULIO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTEntrada("./altamira/2022/8. AGOSTO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTEntrada("./altamira/2022/9. SEPTIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTEntrada("./altamira/2022/10. OCTUBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTEntrada("./altamira/2022/11. NOVIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTEntrada("./altamira/2022/12. DICIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)

# %% [markdown]
# ### Representar histogramas

# %%
def HistogramaTEntrada(FicheroEntrada, m, divisiones, MesAño, minVariable, maxVariable):
    #Sacar el histograma
    df = pd.read_excel(FicheroEntrada)
    bins = np.linspace(df['Temperatura A (° C)'].min(), df['Temperatura A (° C)'].max(), divisiones)
    np.histogram(df['Temperatura A (° C)'], bins=bins)
    plt.ylim(0, m)
    plt.xlim(minVariable,maxVariable)
    #Pintarlo+leyenda
    plt.grid()
    plt.hist(df['Temperatura A (° C)'], bins=divisiones, edgecolor='black')
    plt.title(MesAño)
    plt.xlabel("Temperatura Entrada / ºC")
    plt.ylabel("Frecuencia")
    plt.gca().set_axisbelow(True)
    plt.show()

# %%
#Prueba:
# HistogramaTEntrada("./altamira/2020/10.OCTUBRE/ZONA ENTRADA.xlsx", m, divisiones, 'Octubre 2020', minVariable, maxVariable)

# %%
# 2020
HistogramaTEntrada("./altamira/2020/10.OCTUBRE/ZONA ENTRADA.xlsx", m, divisiones, 'Octubre 2020', minVariable, maxVariable)
HistogramaTEntrada("./altamira/2020/11.NOVIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Noviembre 2020', minVariable, maxVariable)
HistogramaTEntrada("./altamira/2020/12.DICIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Diciembre 2020', minVariable, maxVariable)
#2021
HistogramaTEntrada("./altamira/2021/1.ENERO/ZONA ENTRADA ENERO.xlsx", m, divisiones, 'Enero 2021', minVariable, maxVariable)
HistogramaTEntrada("./altamira/2021/2.FEBRERO/ZONA ENTRADA A.xlsx", m, divisiones, 'Febrero 2021', minVariable, maxVariable)
HistogramaTEntrada("./altamira/2021/3.MARZO/ZONA ENTRADA A.xlsx", m, divisiones, 'Marzo 2021', minVariable, maxVariable)
HistogramaTEntrada("./altamira/2021/4.ABRIL/ZONA ENTRADA.xlsx", m, divisiones, 'Abril 2021', minVariable, maxVariable)
HistogramaTEntrada("./altamira/2021/5.MAYO/ZONA ENTRADA A.xlsx", m, divisiones, 'Mayo 2021', minVariable, maxVariable)
HistogramaTEntrada("./altamira/2021/6.JUNIO/ZONA ENTRADA A.xlsx", m, divisiones, 'Junio 2021', minVariable, maxVariable)
HistogramaTEntrada("./altamira/2021/7.JULIO/ZONA ENTRADA A.xlsx", m, divisiones, 'Julio 2021', minVariable, maxVariable)
HistogramaTEntrada("./altamira/2021/8.AGOSTO/ZONA ENTRADA A.xlsx", m, divisiones, 'Agosto 2021', minVariable, maxVariable)
HistogramaTEntrada("./altamira/2021/9. SEPTIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Septiembre 2021', minVariable, maxVariable)
HistogramaTEntrada("./altamira/2021/10. OCTUBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Octubre 2021', minVariable, maxVariable)
HistogramaTEntrada("./altamira/2021/11. NOVIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Noviembre 2021', minVariable, maxVariable)
HistogramaTEntrada("./altamira/2021/12. DICIEMBRE/ZONA ENTRADA.xlsx", m, divisiones, 'Diciembre 2021', minVariable, maxVariable)
#2022
HistogramaTEntrada("./altamira/2022/1.ENERO/ZONA ENTRADA A.xlsx", m, divisiones, 'Enero 2022', minVariable, maxVariable)
HistogramaTEntrada("./altamira/2022/2.FEBRERO/ZONA ENTRADA A.xlsx", m, divisiones, 'Febrero 2022', minVariable, maxVariable)
HistogramaTEntrada("./altamira/2022/3.MARZO/ZONA ENTRADA A.xlsx", m, divisiones, 'Marzo 2022', minVariable, maxVariable)
HistogramaTEntrada("./altamira/2022/4.ABRIL/ZONA ENTRADA A.xlsx", m, divisiones, 'Abril 2022', minVariable, maxVariable)
HistogramaTEntrada("./altamira/2022/5.MAYO/ZONA ENTRADA.xlsx", m, divisiones, 'Mayo 2022', minVariable, maxVariable)
HistogramaTEntrada("./altamira/2022/6. JUNIO/ZONA ENTRADA.xlsx", m, divisiones, 'Junio 2022', minVariable, maxVariable)
HistogramaTEntrada("./altamira/2022/7.JULIO/ZONA ENTRADA A.xlsx", m, divisiones, 'Julio 2022', minVariable, maxVariable)
HistogramaTEntrada("./altamira/2022/8. AGOSTO/ZONA ENTRADA A.xlsx", m, divisiones, 'Agosto 2022', minVariable, maxVariable)
HistogramaTEntrada("./altamira/2022/9. SEPTIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Septiembre 2022', minVariable, maxVariable)
HistogramaTEntrada("./altamira/2022/10. OCTUBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Octubre 2022', minVariable, maxVariable)
HistogramaTEntrada("./altamira/2022/11. NOVIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Noviembre 2022', minVariable, maxVariable)
HistogramaTEntrada("./altamira/2022/12. DICIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Diciembre 2022', minVariable, maxVariable)

# %% [markdown]
# # 2. Histogramas de la temperatura de Entrada suavizada

# %% [markdown]
# ### Sacar el máximo de veces que se repite un dato en los histogramas:

# %%
m=0 #Máximo de datos por columna hasta este momento
minVariable=100000000000#Minimo  para comparar de la variable a representar
maxVariable=0#Máximo para comparar de la variable a representar
def AlturaTsuavEntrada(FicheroEntrada, m, divisiones, minVariable, maxVariable):
#     print('---------------------------------------------------------------')
    df = pd.read_excel(FicheroEntrada)
    min_relativo=df['Th_suavizada'].min()
    max_relativo=df['Th_suavizada'].max()
    bins = np.linspace(min_relativo, max_relativo, divisiones)
    hist, bins = np.histogram(df['Th_suavizada'], bins=bins)
#     print('Máximo de datos por columna hasta ahora:', m)
    for i in range(len(hist)):
#         print(f"Intervalo {i+1}: {hist[i]} datos")
        if hist[i]>m:
            m=hist[i]
            
    #Igualar la escala en x:
    if min_relativo<minVariable:
        minVariable=min_relativo
    if max_relativo>maxVariable:
        maxVariable=max_relativo
    return m, minVariable, maxVariable

# %%
# m, minVariable, maxVariable = AlturaTsuavEntrada("./altamira/2020/10.OCTUBRE/ZONA ENTRADA.xlsx", m, divisiones, minVariable, maxVariable)

# %%
2020
m, minVariable, maxVariable = AlturaTsuavEntrada("./altamira/2020/10.OCTUBRE/ZONA ENTRADA.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavEntrada("./altamira/2020/11.NOVIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavEntrada("./altamira/2020/12.DICIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
#2021
m, minVariable, maxVariable = AlturaTsuavEntrada("./altamira/2021/1.ENERO/ZONA ENTRADA ENERO.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavEntrada("./altamira/2021/2.FEBRERO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavEntrada("./altamira/2021/3.MARZO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavEntrada("./altamira/2021/4.ABRIL/ZONA ENTRADA.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavEntrada("./altamira/2021/5.MAYO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavEntrada("./altamira/2021/6.JUNIO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavEntrada("./altamira/2021/7.JULIO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavEntrada("./altamira/2021/8.AGOSTO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavEntrada("./altamira/2021/9. SEPTIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavEntrada("./altamira/2021/10. OCTUBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavEntrada("./altamira/2021/11. NOVIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavEntrada("./altamira/2021/12. DICIEMBRE/ZONA ENTRADA.xlsx", m, divisiones, minVariable, maxVariable)
#2022
m, minVariable, maxVariable = AlturaTsuavEntrada("./altamira/2022/1.ENERO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavEntrada("./altamira/2022/2.FEBRERO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavEntrada("./altamira/2022/3.MARZO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavEntrada("./altamira/2022/4.ABRIL/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavEntrada("./altamira/2022/5.MAYO/ZONA ENTRADA.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavEntrada("./altamira/2022/6. JUNIO/ZONA ENTRADA.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavEntrada("./altamira/2022/7.JULIO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavEntrada("./altamira/2022/8. AGOSTO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavEntrada("./altamira/2022/9. SEPTIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavEntrada("./altamira/2022/10. OCTUBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavEntrada("./altamira/2022/11. NOVIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavEntrada("./altamira/2022/12. DICIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)

# %% [markdown]
# ### Representar histogramas

# %%
def HistogramaTsuavEntrada(FicheroEntrada, m, divisiones, MesAño, minVariable, maxVariable):
    #Sacar el histograma
    df = pd.read_excel(FicheroEntrada)
    bins = np.linspace(df['Th_suavizada'].min(), df['Th_suavizada'].max(), divisiones)
    np.histogram(df['Th_suavizada'], bins=bins)
    plt.ylim(0, m)
    plt.xlim(minVariable,maxVariable)
    #Pintarlo+leyenda
    plt.grid()
    plt.hist(df['Th_suavizada'], bins=divisiones, edgecolor='black')
    plt.title(MesAño)
    plt.xlabel("Temperatura Entrada suavizada / ºC")
    plt.ylabel("Frecuencia")
    plt.gca().set_axisbelow(True)
    plt.show()

# %%
# HistogramaTsuavEntrada("./altamira/2020/10.OCTUBRE/ZONA ENTRADA.xlsx", m, divisiones, 'Octubre 2020', minVariable, maxVariable)

# %%
# 2020
HistogramaTsuavEntrada("./altamira/2020/10.OCTUBRE/ZONA ENTRADA.xlsx", m, divisiones, 'Octubre 2020', minVariable, maxVariable)
HistogramaTsuavEntrada("./altamira/2020/11.NOVIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Noviembre 2020', minVariable, maxVariable)
HistogramaTsuavEntrada("./altamira/2020/12.DICIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Diciembre 2020', minVariable, maxVariable)
#2021
HistogramaTsuavEntrada("./altamira/2021/1.ENERO/ZONA ENTRADA ENERO.xlsx", m, divisiones, 'Enero 2021', minVariable, maxVariable)
HistogramaTsuavEntrada("./altamira/2021/2.FEBRERO/ZONA ENTRADA A.xlsx", m, divisiones, 'Febrero 2021', minVariable, maxVariable)
HistogramaTsuavEntrada("./altamira/2021/3.MARZO/ZONA ENTRADA A.xlsx", m, divisiones, 'Marzo 2021', minVariable, maxVariable)
HistogramaTsuavEntrada("./altamira/2021/4.ABRIL/ZONA ENTRADA.xlsx", m, divisiones, 'Abril 2021', minVariable, maxVariable)
HistogramaTsuavEntrada("./altamira/2021/5.MAYO/ZONA ENTRADA A.xlsx", m, divisiones, 'Mayo 2021', minVariable, maxVariable)
HistogramaTsuavEntrada("./altamira/2021/6.JUNIO/ZONA ENTRADA A.xlsx", m, divisiones, 'Junio 2021', minVariable, maxVariable)
HistogramaTsuavEntrada("./altamira/2021/7.JULIO/ZONA ENTRADA A.xlsx", m, divisiones, 'Julio 2021', minVariable, maxVariable)
HistogramaTsuavEntrada("./altamira/2021/8.AGOSTO/ZONA ENTRADA A.xlsx", m, divisiones, 'Agosto 2021', minVariable, maxVariable)
HistogramaTsuavEntrada("./altamira/2021/9. SEPTIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Septiembre 2021', minVariable, maxVariable)
HistogramaTsuavEntrada("./altamira/2021/10. OCTUBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Octubre 2021', minVariable, maxVariable)
HistogramaTsuavEntrada("./altamira/2021/11. NOVIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Noviembre 2021', minVariable, maxVariable)
HistogramaTsuavEntrada("./altamira/2021/12. DICIEMBRE/ZONA ENTRADA.xlsx", m, divisiones, 'Diciembre 2021', minVariable, maxVariable)
#2022
HistogramaTsuavEntrada("./altamira/2022/1.ENERO/ZONA ENTRADA A.xlsx", m, divisiones, 'Enero 2022', minVariable, maxVariable)
HistogramaTsuavEntrada("./altamira/2022/2.FEBRERO/ZONA ENTRADA A.xlsx", m, divisiones, 'Febrero 2022', minVariable, maxVariable)
HistogramaTsuavEntrada("./altamira/2022/3.MARZO/ZONA ENTRADA A.xlsx", m, divisiones, 'Marzo 2022', minVariable, maxVariable)
HistogramaTsuavEntrada("./altamira/2022/4.ABRIL/ZONA ENTRADA A.xlsx", m, divisiones, 'Abril 2022', minVariable, maxVariable)
HistogramaTsuavEntrada("./altamira/2022/5.MAYO/ZONA ENTRADA.xlsx", m, divisiones, 'Mayo 2022', minVariable, maxVariable)
HistogramaTsuavEntrada("./altamira/2022/6. JUNIO/ZONA ENTRADA.xlsx", m, divisiones, 'Junio 2022', minVariable, maxVariable)
HistogramaTsuavEntrada("./altamira/2022/7.JULIO/ZONA ENTRADA A.xlsx", m, divisiones, 'Julio 2022', minVariable, maxVariable)
HistogramaTsuavEntrada("./altamira/2022/8. AGOSTO/ZONA ENTRADA A.xlsx", m, divisiones, 'Agosto 2022', minVariable, maxVariable)
HistogramaTsuavEntrada("./altamira/2022/9. SEPTIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Septiembre 2022', minVariable, maxVariable)
HistogramaTsuavEntrada("./altamira/2022/10. OCTUBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Octubre 2022', minVariable, maxVariable)
HistogramaTsuavEntrada("./altamira/2022/11. NOVIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Noviembre 2022', minVariable, maxVariable)
HistogramaTsuavEntrada("./altamira/2022/12. DICIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Diciembre 2022', minVariable, maxVariable)

# %% [markdown]
# # 3. Histogramas de la cantidad de CO2 de Entrada sin suavizar

# %% [markdown]
# ### Sacar el máximo de veces que se repite un dato en los histogramas:

# %%
m=0 #Máximo de datos por columna hasta este momento
minVariable=100000000000#Minimo  para comparar de la variable a representar
maxVariable=0#Máximo para comparar de la variable a representar
def AlturaCO2Entrada(FicheroEntrada, m, divisiones, minVariable, maxVariable):
#     print('---------------------------------------------------------------')
    df = pd.read_excel(FicheroEntrada)
    min_relativo=df['CO2 A (ppm)'].min()
    max_relativo=df['CO2 A (ppm)'].max()
    bins = np.linspace(min_relativo, max_relativo, divisiones)
    hist, bins = np.histogram(df['CO2 A (ppm)'], bins=bins)
#     print('Máximo de datos por columna hasta ahora:', m)
    for i in range(len(hist)):
#         print(f"Intervalo {i+1}: {hist[i]} datos")
        if hist[i]>m:
            m=hist[i]
    #Igualar la escala en x:
    if min_relativo<minVariable:
        minVariable=min_relativo
    if max_relativo>maxVariable:
        maxVariable=max_relativo
    return m, minVariable, maxVariable

# %%
# m, minVariable, maxVariable = AlturaCO2Entrada("./altamira/2020/10.OCTUBRE/ZONA ENTRADA.xlsx", m, divisiones, minVariable, maxVariable)

# %%
2020
m, minVariable, maxVariable = AlturaCO2Entrada("./altamira/2020/10.OCTUBRE/ZONA ENTRADA.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Entrada("./altamira/2020/11.NOVIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Entrada("./altamira/2020/12.DICIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
#2021
m, minVariable, maxVariable = AlturaCO2Entrada("./altamira/2021/1.ENERO/ZONA ENTRADA ENERO.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Entrada("./altamira/2021/2.FEBRERO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Entrada("./altamira/2021/3.MARZO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Entrada("./altamira/2021/4.ABRIL/ZONA ENTRADA.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Entrada("./altamira/2021/5.MAYO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Entrada("./altamira/2021/6.JUNIO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Entrada("./altamira/2021/7.JULIO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Entrada("./altamira/2021/8.AGOSTO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Entrada("./altamira/2021/9. SEPTIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Entrada("./altamira/2021/10. OCTUBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Entrada("./altamira/2021/11. NOVIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Entrada("./altamira/2021/12. DICIEMBRE/ZONA ENTRADA.xlsx", m, divisiones, minVariable, maxVariable)
#2022
m, minVariable, maxVariable = AlturaCO2Entrada("./altamira/2022/1.ENERO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Entrada("./altamira/2022/2.FEBRERO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Entrada("./altamira/2022/3.MARZO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Entrada("./altamira/2022/4.ABRIL/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Entrada("./altamira/2022/5.MAYO/ZONA ENTRADA.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Entrada("./altamira/2022/6. JUNIO/ZONA ENTRADA.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Entrada("./altamira/2022/7.JULIO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Entrada("./altamira/2022/8. AGOSTO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Entrada("./altamira/2022/9. SEPTIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Entrada("./altamira/2022/10. OCTUBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Entrada("./altamira/2022/11. NOVIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Entrada("./altamira/2022/12. DICIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)

# %% [markdown]
# ### Representar histogramas

# %%
def HistogramaCO2Entrada(FicheroEntrada, m, divisiones, MesAño, minVariable, maxVariable):
    #Sacar el histograma
    df = pd.read_excel(FicheroEntrada)
    bins = np.linspace(df['CO2 A (ppm)'].min(), df['CO2 A (ppm)'].max(), divisiones)
    np.histogram(df['CO2 A (ppm)'], bins=bins)
    plt.ylim(0, m)
    plt.xlim(minVariable,maxVariable)
    #Pintarlo+leyenda
    plt.grid()
    plt.hist(df['CO2 A (ppm)'], bins=divisiones, edgecolor='black')
    plt.title(MesAño)
    plt.xlabel("CO2 Entrada / ºC")
    plt.ylabel("Frecuencia")
    plt.gca().set_axisbelow(True)
    plt.show()

# %%
# HistogramaCO2Entrada("./altamira/2020/10.OCTUBRE/ZONA ENTRADA.xlsx", m, divisiones, 'Octubre 2020', minVariable, maxVariable)

# %%
# 2020
HistogramaCO2Entrada("./altamira/2020/10.OCTUBRE/ZONA ENTRADA.xlsx", m, divisiones, 'Octubre 2020', minVariable, maxVariable)
HistogramaCO2Entrada("./altamira/2020/11.NOVIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Noviembre 2020', minVariable, maxVariable)
HistogramaCO2Entrada("./altamira/2020/12.DICIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Diciembre 2020', minVariable, maxVariable)
#2021
HistogramaCO2Entrada("./altamira/2021/1.ENERO/ZONA ENTRADA ENERO.xlsx", m, divisiones, 'Enero 2021', minVariable, maxVariable)
HistogramaCO2Entrada("./altamira/2021/2.FEBRERO/ZONA ENTRADA A.xlsx", m, divisiones, 'Febrero 2021', minVariable, maxVariable)
HistogramaCO2Entrada("./altamira/2021/3.MARZO/ZONA ENTRADA A.xlsx", m, divisiones, 'Marzo 2021', minVariable, maxVariable)
HistogramaCO2Entrada("./altamira/2021/4.ABRIL/ZONA ENTRADA.xlsx", m, divisiones, 'Abril 2021', minVariable, maxVariable)
HistogramaCO2Entrada("./altamira/2021/5.MAYO/ZONA ENTRADA A.xlsx", m, divisiones, 'Mayo 2021', minVariable, maxVariable)
HistogramaCO2Entrada("./altamira/2021/6.JUNIO/ZONA ENTRADA A.xlsx", m, divisiones, 'Junio 2021', minVariable, maxVariable)
HistogramaCO2Entrada("./altamira/2021/7.JULIO/ZONA ENTRADA A.xlsx", m, divisiones, 'Julio 2021', minVariable, maxVariable)
HistogramaCO2Entrada("./altamira/2021/8.AGOSTO/ZONA ENTRADA A.xlsx", m, divisiones, 'Agosto 2021', minVariable, maxVariable)
HistogramaCO2Entrada("./altamira/2021/9. SEPTIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Septiembre 2021', minVariable, maxVariable)
HistogramaCO2Entrada("./altamira/2021/10. OCTUBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Octubre 2021', minVariable, maxVariable)
HistogramaCO2Entrada("./altamira/2021/11. NOVIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Noviembre 2021', minVariable, maxVariable)
HistogramaCO2Entrada("./altamira/2021/12. DICIEMBRE/ZONA ENTRADA.xlsx", m, divisiones, 'Diciembre 2021', minVariable, maxVariable)
#2022
HistogramaCO2Entrada("./altamira/2022/1.ENERO/ZONA ENTRADA A.xlsx", m, divisiones, 'Enero 2022', minVariable, maxVariable)
HistogramaCO2Entrada("./altamira/2022/2.FEBRERO/ZONA ENTRADA A.xlsx", m, divisiones, 'Febrero 2022', minVariable, maxVariable)
HistogramaCO2Entrada("./altamira/2022/3.MARZO/ZONA ENTRADA A.xlsx", m, divisiones, 'Marzo 2022', minVariable, maxVariable)
HistogramaCO2Entrada("./altamira/2022/4.ABRIL/ZONA ENTRADA A.xlsx", m, divisiones, 'Abril 2022', minVariable, maxVariable)
HistogramaCO2Entrada("./altamira/2022/5.MAYO/ZONA ENTRADA.xlsx", m, divisiones, 'Mayo 2022', minVariable, maxVariable)
HistogramaCO2Entrada("./altamira/2022/6. JUNIO/ZONA ENTRADA.xlsx", m, divisiones, 'Junio 2022', minVariable, maxVariable)
HistogramaCO2Entrada("./altamira/2022/7.JULIO/ZONA ENTRADA A.xlsx", m, divisiones, 'Julio 2022', minVariable, maxVariable)
HistogramaCO2Entrada("./altamira/2022/8. AGOSTO/ZONA ENTRADA A.xlsx", m, divisiones, 'Agosto 2022', minVariable, maxVariable)
HistogramaCO2Entrada("./altamira/2022/9. SEPTIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Septiembre 2022', minVariable, maxVariable)
HistogramaCO2Entrada("./altamira/2022/10. OCTUBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Octubre 2022', minVariable, maxVariable)
HistogramaCO2Entrada("./altamira/2022/11. NOVIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Noviembre 2022', minVariable, maxVariable)
HistogramaCO2Entrada("./altamira/2022/12. DICIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Diciembre 2022', minVariable, maxVariable)

# %% [markdown]
# # 4. Histogramas de la cantidad de CO2 de Entrada suavizada

# %% [markdown]
# ### Sacar el máximo de veces que se repite un dato en los histogramas:

# %%
m=0 #Máximo de datos por columna hasta este momento
minVariable=100000000000#Minimo  para comparar de la variable a representar
maxVariable=0#Máximo para comparar de la variable a representar
def AlturaCO2suavEntrada(FicheroEntrada, m, divisiones, minVariable, maxVariable):
#     print('---------------------------------------------------------------')
    df = pd.read_excel(FicheroEntrada)
    min_relativo=df['CO2h_suavizado'].min()
    max_relativo=df['CO2h_suavizado'].max()
    bins = np.linspace(min_relativo, max_relativo, divisiones)
    hist, bins = np.histogram(df['CO2h_suavizado'], bins=bins)
#     print('Máximo de datos por columna hasta ahora:', m)
    for i in range(len(hist)):
#         print(f"Intervalo {i+1}: {hist[i]} datos")
        if hist[i]>m:
            m=hist[i]
    #Igualar la escala en x:
    if min_relativo<minVariable:
        minVariable=min_relativo
    if max_relativo>maxVariable:
        maxVariable=max_relativo
    return m, minVariable, maxVariable

# %%
# m, minVariable, maxVariable = AlturaCO2suavEntrada("./altamira/2020/10.OCTUBRE/ZONA ENTRADA.xlsx", m, divisiones, minVariable, maxVariable)

# %%
# 2020
m, minVariable, maxVariable = AlturaCO2suavEntrada("./altamira/2020/10.OCTUBRE/ZONA ENTRADA.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavEntrada("./altamira/2020/11.NOVIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavEntrada("./altamira/2020/12.DICIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
#2021
m, minVariable, maxVariable = AlturaCO2suavEntrada("./altamira/2021/1.ENERO/ZONA ENTRADA ENERO.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavEntrada("./altamira/2021/2.FEBRERO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavEntrada("./altamira/2021/3.MARZO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavEntrada("./altamira/2021/4.ABRIL/ZONA ENTRADA.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavEntrada("./altamira/2021/5.MAYO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavEntrada("./altamira/2021/6.JUNIO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavEntrada("./altamira/2021/7.JULIO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavEntrada("./altamira/2021/8.AGOSTO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavEntrada("./altamira/2021/9. SEPTIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavEntrada("./altamira/2021/10. OCTUBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavEntrada("./altamira/2021/11. NOVIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavEntrada("./altamira/2021/12. DICIEMBRE/ZONA ENTRADA.xlsx", m, divisiones, minVariable, maxVariable)
#2022
m, minVariable, maxVariable = AlturaCO2suavEntrada("./altamira/2022/1.ENERO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavEntrada("./altamira/2022/2.FEBRERO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavEntrada("./altamira/2022/3.MARZO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavEntrada("./altamira/2022/4.ABRIL/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavEntrada("./altamira/2022/5.MAYO/ZONA ENTRADA.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavEntrada("./altamira/2022/6. JUNIO/ZONA ENTRADA.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavEntrada("./altamira/2022/7.JULIO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavEntrada("./altamira/2022/8. AGOSTO/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavEntrada("./altamira/2022/9. SEPTIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavEntrada("./altamira/2022/10. OCTUBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavEntrada("./altamira/2022/11. NOVIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavEntrada("./altamira/2022/12. DICIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, minVariable, maxVariable)

# %% [markdown]
# ### Representar histogramas

# %%
def HistogramaCO2suavEntrada(FicheroEntrada, m, divisiones, MesAño, minVariable, maxVariable):
    #Sacar el histograma
    df = pd.read_excel(FicheroEntrada)
    bins = np.linspace(df['CO2h_suavizado'].min(), df['CO2h_suavizado'].max(), divisiones)
    np.histogram(df['CO2h_suavizado'], bins=bins)
    plt.ylim(0, m)
    plt.xlim(minVariable,maxVariable)
    #Pintarlo+leyenda
    plt.grid()
    plt.hist(df['CO2h_suavizado'], bins=divisiones, edgecolor='black')
    plt.title(MesAño)
    plt.xlabel("CO2 suavizado Entrada / ºC")
    plt.ylabel("Frecuencia")
    plt.gca().set_axisbelow(True)
    plt.show()

# %%
# HistogramaCO2suavEntrada("./altamira/2020/10.OCTUBRE/ZONA ENTRADA.xlsx", m, divisiones, 'Octubre 2020', minVariable, maxVariable)

# %%
# 2020
HistogramaCO2suavEntrada("./altamira/2020/10.OCTUBRE/ZONA ENTRADA.xlsx", m, divisiones, 'Octubre 2020', minVariable, maxVariable)
HistogramaCO2suavEntrada("./altamira/2020/11.NOVIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Noviembre 2020', minVariable, maxVariable)
HistogramaCO2suavEntrada("./altamira/2020/12.DICIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Diciembre 2020', minVariable, maxVariable)
#2021
HistogramaCO2suavEntrada("./altamira/2021/1.ENERO/ZONA ENTRADA ENERO.xlsx", m, divisiones, 'Enero 2021', minVariable, maxVariable)
HistogramaCO2suavEntrada("./altamira/2021/2.FEBRERO/ZONA ENTRADA A.xlsx", m, divisiones, 'Febrero 2021', minVariable, maxVariable)
HistogramaCO2suavEntrada("./altamira/2021/3.MARZO/ZONA ENTRADA A.xlsx", m, divisiones, 'Marzo 2021', minVariable, maxVariable)
HistogramaCO2suavEntrada("./altamira/2021/4.ABRIL/ZONA ENTRADA.xlsx", m, divisiones, 'Abril 2021', minVariable, maxVariable)
HistogramaCO2suavEntrada("./altamira/2021/5.MAYO/ZONA ENTRADA A.xlsx", m, divisiones, 'Mayo 2021', minVariable, maxVariable)
HistogramaCO2suavEntrada("./altamira/2021/6.JUNIO/ZONA ENTRADA A.xlsx", m, divisiones, 'Junio 2021', minVariable, maxVariable)
HistogramaCO2suavEntrada("./altamira/2021/7.JULIO/ZONA ENTRADA A.xlsx", m, divisiones, 'Julio 2021', minVariable, maxVariable)
HistogramaCO2suavEntrada("./altamira/2021/8.AGOSTO/ZONA ENTRADA A.xlsx", m, divisiones, 'Agosto 2021', minVariable, maxVariable)
HistogramaCO2suavEntrada("./altamira/2021/9. SEPTIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Septiembre 2021', minVariable, maxVariable)
HistogramaCO2suavEntrada("./altamira/2021/10. OCTUBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Octubre 2021', minVariable, maxVariable)
HistogramaCO2suavEntrada("./altamira/2021/11. NOVIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Noviembre 2021', minVariable, maxVariable)
HistogramaCO2suavEntrada("./altamira/2021/12. DICIEMBRE/ZONA ENTRADA.xlsx", m, divisiones, 'Diciembre 2021', minVariable, maxVariable)
#2022
HistogramaCO2suavEntrada("./altamira/2022/1.ENERO/ZONA ENTRADA A.xlsx", m, divisiones, 'Enero 2022', minVariable, maxVariable)
HistogramaCO2suavEntrada("./altamira/2022/2.FEBRERO/ZONA ENTRADA A.xlsx", m, divisiones, 'Febrero 2022', minVariable, maxVariable)
HistogramaCO2suavEntrada("./altamira/2022/3.MARZO/ZONA ENTRADA A.xlsx", m, divisiones, 'Marzo 2022', minVariable, maxVariable)
HistogramaCO2suavEntrada("./altamira/2022/4.ABRIL/ZONA ENTRADA A.xlsx", m, divisiones, 'Abril 2022', minVariable, maxVariable)
HistogramaCO2suavEntrada("./altamira/2022/5.MAYO/ZONA ENTRADA.xlsx", m, divisiones, 'Mayo 2022', minVariable, maxVariable)
HistogramaCO2suavEntrada("./altamira/2022/6. JUNIO/ZONA ENTRADA.xlsx", m, divisiones, 'Junio 2022', minVariable, maxVariable)
HistogramaCO2suavEntrada("./altamira/2022/7.JULIO/ZONA ENTRADA A.xlsx", m, divisiones, 'Julio 2022', minVariable, maxVariable)
HistogramaCO2suavEntrada("./altamira/2022/8. AGOSTO/ZONA ENTRADA A.xlsx", m, divisiones, 'Agosto 2022', minVariable, maxVariable)
HistogramaCO2suavEntrada("./altamira/2022/9. SEPTIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Septiembre 2022', minVariable, maxVariable)
HistogramaCO2suavEntrada("./altamira/2022/10. OCTUBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Octubre 2022', minVariable, maxVariable)
HistogramaCO2suavEntrada("./altamira/2022/11. NOVIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Noviembre 2022', minVariable, maxVariable)
HistogramaCO2suavEntrada("./altamira/2022/12. DICIEMBRE/ZONA ENTRADA A.xlsx", m, divisiones, 'Diciembre 2022', minVariable, maxVariable)
