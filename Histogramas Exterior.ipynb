# %% [markdown]
# ### Histogramas Exterior:
# Contenido del fichero:
# 1. Histogramas de la temperatura de Exterior sin suavizar
# 2. Histogramas de la temperatura de Exterior suavizada

# %%
# Imports:
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Variables que se pueden modificar:
divisiones = 10 #Numero de intervalos en los que se dividen los datos a representar en el histograma

# %% [markdown]
# # 1. Histogramas de la temperatura de Exterior sin suavizar

# %% [markdown]
# ### Sacar el máximo de veces que se repite un dato en los histogramas:

# %%
m=0 #Máximo de datos por columna hasta este momento
def AlturaTExterior(FicheroExterior, m, divisiones):
#     print('---------------------------------------------------------------')
    df = pd.read_excel(FicheroExterior)
    bins = np.linspace(df["Tr Exterior (C Tr)"].min(), df["Tr Exterior (C Tr)"].max(), divisiones)
    hist, bins = np.histogram(df["Tr Exterior (C Tr)"], bins=bins)
#     print('Máximo de datos por columna hasta ahora:', m)
    for i in range(len(hist)):
#         print(f"Intervalo {i+1}: {hist[i]} datos")
        if hist[i]>m:
            m=hist[i]
    return m

# %%
m=AlturaTExterior("./altamira/2020/10.OCTUBRE/ZONA EXTERIOR.xlsx", m, divisiones)

# %%
2020
# m = AlturaTExterior("./altamira/2020/10.OCTUBRE/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTExterior("./altamira/2020/11.NOVIEMBRE/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTExterior("./altamira/2020/12.DICIEMBRE/ZONA EXTERIOR.xlsx", m, divisiones)
#2021
m = AlturaTExterior("./altamira/2021/1.ENERO/ZONA EXTERIOR ENERO.xlsx", m, divisiones)
m = AlturaTExterior("./altamira/2021/2.FEBRERO/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTExterior("./altamira/2021/3.MARZO/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTExterior("./altamira/2021/4.ABRIL/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTExterior("./altamira/2021/5.MAYO/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTExterior("./altamira/2021/6.JUNIO/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTExterior("./altamira/2021/7.JULIO/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTExterior("./altamira/2021/8.AGOSTO/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTExterior("./altamira/2021/9. SEPTIEMBRE/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTExterior("./altamira/2021/10. OCTUBRE/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTExterior("./altamira/2021/11. NOVIEMBRE/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTExterior("./altamira/2021/12. DICIEMBRE/ZONA EXTERIOR.xlsx", m, divisiones)
#2022
m = AlturaTExterior("./altamira/2022/1.ENERO/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTExterior("./altamira/2022/2.FEBRERO/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTExterior("./altamira/2022/3.MARZO/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTExterior("./altamira/2022/4.ABRIL/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTExterior("./altamira/2022/5.MAYO/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTExterior("./altamira/2022/6. JUNIO/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTExterior("./altamira/2022/7.JULIO/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTExterior("./altamira/2022/8. AGOSTO/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTExterior("./altamira/2022/9. SEPTIEMBRE/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTExterior("./altamira/2022/10. OCTUBRE/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTExterior("./altamira/2022/11. NOVIEMBRE/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTExterior("./altamira/2022/12. DICIEMBRE/ZONA EXTERIOR.xlsx", m, divisiones)

# %% [markdown]
# ### Representar histogramas

# %%
def HistogramaTExterior(FicheroExterior, m, divisiones, MesAño):
    #Sacar el histograma
    df = pd.read_excel(FicheroExterior)
    bins = np.linspace(df["Tr Exterior (C Tr)"].min(), df["Tr Exterior (C Tr)"].max(), divisiones)
    np.histogram(df["Tr Exterior (C Tr)"], bins=bins)
    plt.ylim(0, m)
    #Pintarlo+leyenda
    plt.grid()
    plt.hist(df["Tr Exterior (C Tr)"], bins=divisiones, edgecolor='black')
    plt.title(MesAño)
    plt.xlabel("Temperatura Exterior / ºC")
    plt.ylabel("Frecuencia")
    plt.gca().set_axisbelow(True)
    plt.show()

# %%
#Prueba:
HistogramaTExterior("./altamira/2020/10.OCTUBRE/ZONA EXTERIOR.xlsx", m, divisiones, 'Octubre 2020')

# %%
# 2020
# HistogramaTExterior("./altamira/2020/10.OCTUBRE/ZONA EXTERIOR.xlsx", m, divisiones, 'Octubre 2020')
HistogramaTExterior("./altamira/2020/11.NOVIEMBRE/ZONA EXTERIOR.xlsx", m, divisiones, 'Noviembre 2020')
HistogramaTExterior("./altamira/2020/12.DICIEMBRE/ZONA EXTERIOR.xlsx", m, divisiones, 'Diciembre 2020')
#2021
HistogramaTExterior("./altamira/2021/1.ENERO/ZONA EXTERIOR ENERO.xlsx", m, divisiones, 'Enero 2021')
HistogramaTExterior("./altamira/2021/2.FEBRERO/ZONA EXTERIOR.xlsx", m, divisiones, 'Febrero 2021')
HistogramaTExterior("./altamira/2021/3.MARZO/ZONA EXTERIOR.xlsx", m, divisiones, 'Marzo 2021')
HistogramaTExterior("./altamira/2021/4.ABRIL/ZONA EXTERIOR.xlsx", m, divisiones, 'Abril 2021')
HistogramaTExterior("./altamira/2021/5.MAYO/ZONA EXTERIOR.xlsx", m, divisiones, 'Mayo 2021')
HistogramaTExterior("./altamira/2021/6.JUNIO/ZONA EXTERIOR.xlsx", m, divisiones, 'Junio 2021')
HistogramaTExterior("./altamira/2021/7.JULIO/ZONA EXTERIOR.xlsx", m, divisiones, 'Julio 2021')
HistogramaTExterior("./altamira/2021/8.AGOSTO/ZONA EXTERIOR.xlsx", m, divisiones, 'Agosto 2021')
HistogramaTExterior("./altamira/2021/9. SEPTIEMBRE/ZONA EXTERIOR.xlsx", m, divisiones, 'Septiembre 2021')
HistogramaTExterior("./altamira/2021/10. OCTUBRE/ZONA EXTERIOR.xlsx", m, divisiones, 'Octubre 2021')
HistogramaTExterior("./altamira/2021/11. NOVIEMBRE/ZONA EXTERIOR.xlsx", m, divisiones, 'Noviembre 2021')
HistogramaTExterior("./altamira/2021/12. DICIEMBRE/ZONA EXTERIOR.xlsx", m, divisiones, 'Diciembre 2021')
#2022
HistogramaTExterior("./altamira/2022/1.ENERO/ZONA EXTERIOR.xlsx", m, divisiones, 'Enero 2022')
HistogramaTExterior("./altamira/2022/2.FEBRERO/ZONA EXTERIOR.xlsx", m, divisiones, 'Febrero 2022')
HistogramaTExterior("./altamira/2022/3.MARZO/ZONA EXTERIOR.xlsx", m, divisiones, 'Marzo 2022')
HistogramaTExterior("./altamira/2022/4.ABRIL/ZONA EXTERIOR.xlsx", m, divisiones, 'Abril 2022')
HistogramaTExterior("./altamira/2022/5.MAYO/ZONA EXTERIOR.xlsx", m, divisiones, 'Mayo 2022')
HistogramaTExterior("./altamira/2022/6. JUNIO/ZONA EXTERIOR.xlsx", m, divisiones, 'Junio 2022')
HistogramaTExterior("./altamira/2022/7.JULIO/ZONA EXTERIOR.xlsx", m, divisiones, 'Julio 2022')
HistogramaTExterior("./altamira/2022/8. AGOSTO/ZONA EXTERIOR.xlsx", m, divisiones, 'Agosto 2022')
HistogramaTExterior("./altamira/2022/9. SEPTIEMBRE/ZONA EXTERIOR.xlsx", m, divisiones, 'Septiembre 2022')
HistogramaTExterior("./altamira/2022/10. OCTUBRE/ZONA EXTERIOR.xlsx", m, divisiones, 'Octubre 2022')
HistogramaTExterior("./altamira/2022/11. NOVIEMBRE/ZONA EXTERIOR.xlsx", m, divisiones, 'Noviembre 2022')
HistogramaTExterior("./altamira/2022/12. DICIEMBRE/ZONA EXTERIOR.xlsx", m, divisiones, 'Diciembre 2022')

# %% [markdown]
# # 2. Histogramas de la temperatura de Exterior suavizada

# %% [markdown]
# ### Sacar el máximo de veces que se repite un dato en los histogramas:

# %%
m=0 #Máximo de datos por columna hasta este momento
def AlturaTsuavExterior(FicheroExterior, m, divisiones):
#     print('---------------------------------------------------------------')
    df = pd.read_excel(FicheroExterior)
    bins = np.linspace(df['Te_suavizada'].min(), df['Te_suavizada'].max(), divisiones)
    hist, bins = np.histogram(df['Te_suavizada'], bins=bins)
#     print('Máximo de datos por columna hasta ahora:', m)
    for i in range(len(hist)):
#         print(f"Intervalo {i+1}: {hist[i]} datos")
        if hist[i]>m:
            m=hist[i]
    return m

# %%
m = AlturaTsuavExterior("./altamira/2020/10.OCTUBRE/ZONA EXTERIOR.xlsx", m, divisiones)

# %%
2020
# m = AlturaTsuavExterior("./altamira/2020/10.OCTUBRE/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTsuavExterior("./altamira/2020/11.NOVIEMBRE/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTsuavExterior("./altamira/2020/12.DICIEMBRE/ZONA EXTERIOR.xlsx", m, divisiones)
#2021
m = AlturaTsuavExterior("./altamira/2021/1.ENERO/ZONA EXTERIOR ENERO.xlsx", m, divisiones)
m = AlturaTsuavExterior("./altamira/2021/2.FEBRERO/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTsuavExterior("./altamira/2021/3.MARZO/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTsuavExterior("./altamira/2021/4.ABRIL/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTsuavExterior("./altamira/2021/5.MAYO/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTsuavExterior("./altamira/2021/6.JUNIO/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTsuavExterior("./altamira/2021/7.JULIO/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTsuavExterior("./altamira/2021/8.AGOSTO/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTsuavExterior("./altamira/2021/9. SEPTIEMBRE/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTsuavExterior("./altamira/2021/10. OCTUBRE/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTsuavExterior("./altamira/2021/11. NOVIEMBRE/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTsuavExterior("./altamira/2021/12. DICIEMBRE/ZONA EXTERIOR.xlsx", m, divisiones)
#2022
m = AlturaTsuavExterior("./altamira/2022/1.ENERO/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTsuavExterior("./altamira/2022/2.FEBRERO/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTsuavExterior("./altamira/2022/3.MARZO/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTsuavExterior("./altamira/2022/4.ABRIL/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTsuavExterior("./altamira/2022/5.MAYO/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTsuavExterior("./altamira/2022/6. JUNIO/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTsuavExterior("./altamira/2022/7.JULIO/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTsuavExterior("./altamira/2022/8. AGOSTO/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTsuavExterior("./altamira/2022/9. SEPTIEMBRE/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTsuavExterior("./altamira/2022/10. OCTUBRE/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTsuavExterior("./altamira/2022/11. NOVIEMBRE/ZONA EXTERIOR.xlsx", m, divisiones)
m = AlturaTsuavExterior("./altamira/2022/12. DICIEMBRE/ZONA EXTERIOR.xlsx", m, divisiones)

# %% [markdown]
# ### Representar histogramas

# %%
def HistogramaTsuavExterior(FicheroExterior, m, divisiones, MesAño):
    #Sacar el histograma
    df = pd.read_excel(FicheroExterior)
    bins = np.linspace(df['Te_suavizada'].min(), df['Te_suavizada'].max(), divisiones)
    np.histogram(df['Te_suavizada'], bins=bins)
    plt.ylim(0, m)
    #Pintarlo+leyenda
    plt.grid()
    plt.hist(df['Te_suavizada'], bins=divisiones, edgecolor='black')
    plt.title(MesAño)
    plt.xlabel("Temperatura Exterior suavizada / ºC")
    plt.ylabel("Frecuencia")
    plt.gca().set_axisbelow(True)
    plt.show()

# %%
HistogramaTsuavExterior("./altamira/2020/10.OCTUBRE/ZONA POLICROMOS.xlsx", m, divisiones, 'Octubre 2020')

# %%
# 2020
# HistogramaTsuavExterior("./altamira/2020/10.OCTUBRE/ZONA POLICROMOS.xlsx", m, divisiones, 'Octubre 2020')
HistogramaTsuavExterior("./altamira/2020/11.NOVIEMBRE/ZONA POLICROMOS C.xlsx", m, divisiones, 'Noviembre 2020')
HistogramaTsuavExterior("./altamira/2020/12.DICIEMBRE/ZONA POLICROMOS C.xlsx", m, divisiones, 'Diciembre 2020')
#2021
HistogramaTsuavExterior("./altamira/2021/1.ENERO/ZONA POLICROMOS ENERO.xlsx", m, divisiones, 'Enero 2021')
HistogramaTsuavExterior("./altamira/2021/2.FEBRERO/ZONA POLICROMOS C.xlsx", m, divisiones, 'Febrero 2021')
HistogramaTsuavExterior("./altamira/2021/3.MARZO/ZONA POLICROMOS C.xlsx", m, divisiones, 'Marzo 2021')
HistogramaTsuavExterior("./altamira/2021/4.ABRIL/ZONA POLICROMOS C.xlsx", m, divisiones, 'Abril 2021')
HistogramaTsuavExterior("./altamira/2021/5.MAYO/ZONA POLICROMOS C.xlsx", m, divisiones, 'Mayo 2021')
HistogramaTsuavExterior("./altamira/2021/6.JUNIO/ZONA POLICROMOS C.xlsx", m, divisiones, 'Junio 2021')
HistogramaTsuavExterior("./altamira/2021/7.JULIO/ZONA POLICROMOS C.xlsx", m, divisiones, 'Julio 2021')
HistogramaTsuavExterior("./altamira/2021/8.AGOSTO/ZONA POLICROMOS C.xlsx", m, divisiones, 'Agosto 2021')
HistogramaTsuavExterior("./altamira/2021/9. SEPTIEMBRE/ZONA POLICROMOS C.xlsx", m, divisiones, 'Septiembre 2021')
HistogramaTsuavExterior("./altamira/2021/10. OCTUBRE/ZONA POLICROMOS.xlsx", m, divisiones, 'Octubre 2021')
HistogramaTsuavExterior("./altamira/2021/11. NOVIEMBRE/ZONA POLICROMOS.xlsx", m, divisiones, 'Noviembre 2021')
HistogramaTsuavExterior("./altamira/2021/12. DICIEMBRE/ZONA POLICROMOS.xlsx", m, divisiones, 'Diciembre 2021')
#2022
HistogramaTsuavExterior("./altamira/2022/1.ENERO/ZONA POLICROMOS C.xlsx", m, divisiones, 'Enero 2022')
HistogramaTsuavExterior("./altamira/2022/2.FEBRERO/ZONA POLICROMOS C.xlsx", m, divisiones, 'Febrero 2022')
HistogramaTsuavExterior("./altamira/2022/3.MARZO/ZONA POLICROMOS C.xlsx", m, divisiones, 'Marzo 2022')
HistogramaTsuavExterior("./altamira/2022/4.ABRIL/ZONA POLICROMOS C.xlsx", m, divisiones, 'Abril 2022')
HistogramaTsuavExterior("./altamira/2022/5.MAYO/ZONA POLICROMOS.xlsx", m, divisiones, 'Mayo 2022')
HistogramaTsuavExterior("./altamira/2022/6. JUNIO/ZONA POLICROMOS C.xlsx", m, divisiones, 'Junio 2022')
HistogramaTsuavExterior("./altamira/2022/7.JULIO/ZONA POLICROMOS C.xlsx", m, divisiones, 'Julio 2022')
HistogramaTsuavExterior("./altamira/2022/8. AGOSTO/ZONA POLICROMOS C.xlsx", m, divisiones, 'Agosto 2022')
HistogramaTsuavExterior("./altamira/2022/9. SEPTIEMBRE/ZONA POLICROMOS C.xlsx", m, divisiones, 'Septiembre 2022')
HistogramaTsuavExterior("./altamira/2022/10. OCTUBRE/ZONA POLICROMOS C.xlsx", m, divisiones, 'Octubre 2022')
HistogramaTsuavExterior("./altamira/2022/11. NOVIEMBRE/ZONA POLICROMOS C.xlsx", m, divisiones, 'Noviembre 2022')
HistogramaTsuavExterior("./altamira/2022/12. DICIEMBRE/ZONA POLICROMOS.xlsx", m, divisiones, 'Diciembre 2022')
