# %% [markdown]
# ### Histogramas Polícromos:
# Contenido del fichero:
# 1. Histogramas de la temperatura de Policromos sin suavizar
# 2. Histogramas de la temperatura de Policromos suavizada
# 3. Histogramas de la cantidad de CO2 de Policromos sin suavizar
# 4. Histogramas de la cantidad de CO2 de Policromos suavizada
#
# Todos los histogramas se representaron entre los valores extremos del conjunto de datos para poder compararlos más fácilmente entre si.

# %%
#Código necesario para correr funciones desde otro archivo .ipynb de la misma carpeta
# %run FuncionesAjustarIntervalosHistogramas.ipynb
# %run FuncionesRepresentarHistogramas.ipynb

# %%
# Variables que se pueden modificar:
divisiones = 10 #Numero de intervalos en los que se dividen los datos a representar en el histograma

# %% [markdown]
# # 1. Histogramas de la temperatura de Policromos sin suavizar
# ### Obtener la altura y anchura de los histogramas:

# %%
#Fijar las variables de referencia:
m=0 #Máximo de datos por columna hasta este momento
minVariable=100000000000#Minimo  para comparar de la variable a representar
maxVariable=0#Máximo para comparar de la variable a representar

# %%
#Obtener la altura y la anchura de los histogramas:
2020
m, minVariable, maxVariable = AlturaTPolicromos("./altamira/2020/10.OCTUBRE/ZONA POLICROMOS.xlsx",
                                                m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTPolicromos("./altamira/2020/11.NOVIEMBRE/ZONA POLICROMOS C.xlsx",
                                                m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTPolicromos("./altamira/2020/12.DICIEMBRE/ZONA POLICROMOS C.xlsx",
                                                m, divisiones, minVariable, maxVariable)
#2021
m, minVariable, maxVariable = AlturaTPolicromos("./altamira/2021/1.ENERO/ZONA POLICROMOS ENERO.xlsx",
                                                m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTPolicromos("./altamira/2021/2.FEBRERO/ZONA POLICROMOS C.xlsx",
                                                m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTPolicromos("./altamira/2021/3.MARZO/ZONA POLICROMOS C.xlsx",
                                                m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTPolicromos("./altamira/2021/4.ABRIL/ZONA POLICROMOS C.xlsx",
                                                m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTPolicromos("./altamira/2021/5.MAYO/ZONA POLICROMOS C.xlsx",
                                                m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTPolicromos("./altamira/2021/6.JUNIO/ZONA POLICROMOS C.xlsx",
                                                m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTPolicromos("./altamira/2021/7.JULIO/ZONA POLICROMOS C.xlsx",
                                                m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTPolicromos("./altamira/2021/8.AGOSTO/ZONA POLICROMOS C.xlsx",
                                                m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTPolicromos("./altamira/2021/9. SEPTIEMBRE/ZONA POLICROMOS C.xlsx",
                                                m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTPolicromos("./altamira/2021/10. OCTUBRE/ZONA POLICROMOS.xlsx",
                                                m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTPolicromos("./altamira/2021/11. NOVIEMBRE/ZONA POLICROMOS.xlsx",
                                                m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTPolicromos("./altamira/2021/12. DICIEMBRE/ZONA POLICROMOS.xlsx",
                                                m, divisiones, minVariable, maxVariable)
#2022
m, minVariable, maxVariable = AlturaTPolicromos("./altamira/2022/1.ENERO/ZONA POLICROMOS C.xlsx",
                                                m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTPolicromos("./altamira/2022/2.FEBRERO/ZONA POLICROMOS C.xlsx",
                                                m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTPolicromos("./altamira/2022/3.MARZO/ZONA POLICROMOS C.xlsx",
                                                m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTPolicromos("./altamira/2022/4.ABRIL/ZONA POLICROMOS C.xlsx",
                                                m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTPolicromos("./altamira/2022/5.MAYO/ZONA POLICROMOS.xlsx",
                                                m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTPolicromos("./altamira/2022/6. JUNIO/ZONA POLICROMOS C.xlsx",
                                                m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTPolicromos("./altamira/2022/7.JULIO/ZONA POLICROMOS C.xlsx", 
                                                m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTPolicromos("./altamira/2022/8. AGOSTO/ZONA POLICROMOS C.xlsx",
                                                m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTPolicromos("./altamira/2022/9. SEPTIEMBRE/ZONA POLICROMOS C.xlsx",
                                                m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTPolicromos("./altamira/2022/10. OCTUBRE/ZONA POLICROMOS C.xlsx",
                                                m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTPolicromos("./altamira/2022/11. NOVIEMBRE/ZONA POLICROMOS C.xlsx",
                                                m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTPolicromos("./altamira/2022/12. DICIEMBRE/ZONA POLICROMOS.xlsx",
                                                m, divisiones, minVariable, maxVariable)

# %% [markdown]
# ### Representar histogramas

# %%
#Representar histogramas
# 2020
HistogramaTPolicromos("./altamira/2020/10.OCTUBRE/ZONA POLICROMOS.xlsx", m, divisiones,
                      'Octubre 2020', minVariable, maxVariable)
HistogramaTPolicromos("./altamira/2020/11.NOVIEMBRE/ZONA POLICROMOS C.xlsx", m, divisiones,
                      'Noviembre 2020', minVariable, maxVariable)
HistogramaTPolicromos("./altamira/2020/12.DICIEMBRE/ZONA POLICROMOS C.xlsx", m, divisiones,
                      'Diciembre 2020', minVariable, maxVariable)
#2021
HistogramaTPolicromos("./altamira/2021/1.ENERO/ZONA POLICROMOS ENERO.xlsx", m, divisiones,
                      'Enero 2021', minVariable, maxVariable)
HistogramaTPolicromos("./altamira/2021/2.FEBRERO/ZONA POLICROMOS C.xlsx", m, divisiones,
                      'Febrero 2021', minVariable, maxVariable)
HistogramaTPolicromos("./altamira/2021/3.MARZO/ZONA POLICROMOS C.xlsx", m, divisiones,
                      'Marzo 2021', minVariable, maxVariable)
HistogramaTPolicromos("./altamira/2021/4.ABRIL/ZONA POLICROMOS C.xlsx", m, divisiones,
                      'Abril 2021', minVariable, maxVariable)
HistogramaTPolicromos("./altamira/2021/5.MAYO/ZONA POLICROMOS C.xlsx", m, divisiones,
                      'Mayo 2021', minVariable, maxVariable)
HistogramaTPolicromos("./altamira/2021/6.JUNIO/ZONA POLICROMOS C.xlsx", m, divisiones,
                      'Junio 2021', minVariable, maxVariable)
HistogramaTPolicromos("./altamira/2021/7.JULIO/ZONA POLICROMOS C.xlsx", m, divisiones,
                      'Julio 2021', minVariable, maxVariable)
HistogramaTPolicromos("./altamira/2021/8.AGOSTO/ZONA POLICROMOS C.xlsx", m, divisiones,
                      'Agosto 2021', minVariable, maxVariable)
HistogramaTPolicromos("./altamira/2021/9. SEPTIEMBRE/ZONA POLICROMOS C.xlsx", m, divisiones,
                      'Septiembre 2021', minVariable, maxVariable)
HistogramaTPolicromos("./altamira/2021/10. OCTUBRE/ZONA POLICROMOS.xlsx", m, divisiones,
                      'Octubre 2021', minVariable, maxVariable)
HistogramaTPolicromos("./altamira/2021/11. NOVIEMBRE/ZONA POLICROMOS.xlsx", m, divisiones,
                      'Noviembre 2021', minVariable, maxVariable)
HistogramaTPolicromos("./altamira/2021/12. DICIEMBRE/ZONA POLICROMOS.xlsx", m, divisiones,
                      'Diciembre 2021', minVariable, maxVariable)
#2022
HistogramaTPolicromos("./altamira/2022/1.ENERO/ZONA POLICROMOS C.xlsx", m, divisiones,
                      'Enero 2022', minVariable, maxVariable)
HistogramaTPolicromos("./altamira/2022/2.FEBRERO/ZONA POLICROMOS C.xlsx", m, divisiones,
                      'Febrero 2022', minVariable, maxVariable)
HistogramaTPolicromos("./altamira/2022/3.MARZO/ZONA POLICROMOS C.xlsx", m, divisiones,
                      'Marzo 2022', minVariable, maxVariable)
HistogramaTPolicromos("./altamira/2022/4.ABRIL/ZONA POLICROMOS C.xlsx", m, divisiones,
                      'Abril 2022', minVariable, maxVariable)
HistogramaTPolicromos("./altamira/2022/5.MAYO/ZONA POLICROMOS.xlsx", m, divisiones,
                      'Mayo 2022', minVariable, maxVariable)
HistogramaTPolicromos("./altamira/2022/6. JUNIO/ZONA POLICROMOS C.xlsx", m, divisiones,
                      'Junio 2022', minVariable, maxVariable)
HistogramaTPolicromos("./altamira/2022/7.JULIO/ZONA POLICROMOS C.xlsx", m, divisiones,
                      'Julio 2022', minVariable, maxVariable)
HistogramaTPolicromos("./altamira/2022/8. AGOSTO/ZONA POLICROMOS C.xlsx", m, divisiones,
                      'Agosto 2022', minVariable, maxVariable)
HistogramaTPolicromos("./altamira/2022/9. SEPTIEMBRE/ZONA POLICROMOS C.xlsx", m, divisiones,
                      'Septiembre 2022', minVariable, maxVariable)
HistogramaTPolicromos("./altamira/2022/10. OCTUBRE/ZONA POLICROMOS C.xlsx", m, divisiones,
                      'Octubre 2022', minVariable, maxVariable)
HistogramaTPolicromos("./altamira/2022/11. NOVIEMBRE/ZONA POLICROMOS C.xlsx", m, divisiones,
                      'Noviembre 2022', minVariable, maxVariable)
HistogramaTPolicromos("./altamira/2022/12. DICIEMBRE/ZONA POLICROMOS.xlsx", m, divisiones,
                      'Diciembre 2022', minVariable, maxVariable)

# %% [markdown]
# # 2. Histogramas de la temperatura de Policromos suavizada
# ### Obtener la altura y anchura de los histogramas:

# %%
#Resetear las variables de referencia:
m=0 #Máximo de datos por columna hasta este momento
minVariable=100000000000#Minimo  para comparar de la variable a representar
maxVariable=0#Máximo para comparar de la variable a representar

# %%
2020
m, minVariable, maxVariable = AlturaTsuavPolicromos("./altamira/2020/10.OCTUBRE/ZONA POLICROMOS.xlsx",
                                                    m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavPolicromos("./altamira/2020/11.NOVIEMBRE/ZONA POLICROMOS C.xlsx",
                                                    m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavPolicromos("./altamira/2020/12.DICIEMBRE/ZONA POLICROMOS C.xlsx",
                                                    m, divisiones, minVariable, maxVariable)
#2021
m, minVariable, maxVariable = AlturaTsuavPolicromos("./altamira/2021/1.ENERO/ZONA POLICROMOS ENERO.xlsx",
                                                    m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavPolicromos("./altamira/2021/2.FEBRERO/ZONA POLICROMOS C.xlsx",
                                                    m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavPolicromos("./altamira/2021/3.MARZO/ZONA POLICROMOS C.xlsx",
                                                    m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavPolicromos("./altamira/2021/4.ABRIL/ZONA POLICROMOS C.xlsx",
                                                    m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavPolicromos("./altamira/2021/5.MAYO/ZONA POLICROMOS C.xlsx",
                                                    m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavPolicromos("./altamira/2021/6.JUNIO/ZONA POLICROMOS C.xlsx",
                                                    m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavPolicromos("./altamira/2021/7.JULIO/ZONA POLICROMOS C.xlsx",
                                                    m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavPolicromos("./altamira/2021/8.AGOSTO/ZONA POLICROMOS C.xlsx",
                                                    m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavPolicromos("./altamira/2021/9. SEPTIEMBRE/ZONA POLICROMOS C.xlsx",
                                                    m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavPolicromos("./altamira/2021/10. OCTUBRE/ZONA POLICROMOS.xlsx",
                                                    m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavPolicromos("./altamira/2021/11. NOVIEMBRE/ZONA POLICROMOS.xlsx",
                                                    m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavPolicromos("./altamira/2021/12. DICIEMBRE/ZONA POLICROMOS.xlsx",
                                                    m, divisiones, minVariable, maxVariable)
#2022
m, minVariable, maxVariable = AlturaTsuavPolicromos("./altamira/2022/1.ENERO/ZONA POLICROMOS C.xlsx",
                                                    m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavPolicromos("./altamira/2022/2.FEBRERO/ZONA POLICROMOS C.xlsx",
                                                    m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavPolicromos("./altamira/2022/3.MARZO/ZONA POLICROMOS C.xlsx",
                                                    m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavPolicromos("./altamira/2022/4.ABRIL/ZONA POLICROMOS C.xlsx",
                                                    m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavPolicromos("./altamira/2022/5.MAYO/ZONA POLICROMOS.xlsx", m,
                                                    divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavPolicromos("./altamira/2022/6. JUNIO/ZONA POLICROMOS C.xlsx",
                                                    m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavPolicromos("./altamira/2022/7.JULIO/ZONA POLICROMOS C.xlsx",
                                                    m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavPolicromos("./altamira/2022/8. AGOSTO/ZONA POLICROMOS C.xlsx",
                                                    m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavPolicromos("./altamira/2022/9. SEPTIEMBRE/ZONA POLICROMOS C.xlsx",
                                                    m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavPolicromos("./altamira/2022/10. OCTUBRE/ZONA POLICROMOS C.xlsx",
                                                    m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavPolicromos("./altamira/2022/11. NOVIEMBRE/ZONA POLICROMOS C.xlsx",
                                                    m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaTsuavPolicromos("./altamira/2022/12. DICIEMBRE/ZONA POLICROMOS.xlsx",
                                                    m, divisiones, minVariable, maxVariable)

# %% [markdown]
# ### Representar histogramas

# %%
# 2020
HistogramaTsuavPolicromos("./altamira/2020/10.OCTUBRE/ZONA POLICROMOS.xlsx", m, divisiones, 'Octubre 2020',
                          minVariable, maxVariable)
HistogramaTsuavPolicromos("./altamira/2020/11.NOVIEMBRE/ZONA POLICROMOS C.xlsx", m, divisiones, 'Noviembre 2020',
                          minVariable, maxVariable)
HistogramaTsuavPolicromos("./altamira/2020/12.DICIEMBRE/ZONA POLICROMOS C.xlsx", m, divisiones, 'Diciembre 2020',
                          minVariable, maxVariable)
#2021
HistogramaTsuavPolicromos("./altamira/2021/1.ENERO/ZONA POLICROMOS ENERO.xlsx", m, divisiones, 'Enero 2021',
                          minVariable, maxVariable)
HistogramaTsuavPolicromos("./altamira/2021/2.FEBRERO/ZONA POLICROMOS C.xlsx", m, divisiones, 'Febrero 2021',
                          minVariable, maxVariable)
HistogramaTsuavPolicromos("./altamira/2021/3.MARZO/ZONA POLICROMOS C.xlsx", m, divisiones, 'Marzo 2021',
                          minVariable, maxVariable)
HistogramaTsuavPolicromos("./altamira/2021/4.ABRIL/ZONA POLICROMOS C.xlsx", m, divisiones, 'Abril 2021',
                          minVariable, maxVariable)
HistogramaTsuavPolicromos("./altamira/2021/5.MAYO/ZONA POLICROMOS C.xlsx", m, divisiones, 'Mayo 2021',
                          minVariable, maxVariable)
HistogramaTsuavPolicromos("./altamira/2021/6.JUNIO/ZONA POLICROMOS C.xlsx", m, divisiones, 'Junio 2021',
                          minVariable, maxVariable)
HistogramaTsuavPolicromos("./altamira/2021/7.JULIO/ZONA POLICROMOS C.xlsx", m, divisiones, 'Julio 2021',
                          minVariable, maxVariable)
HistogramaTsuavPolicromos("./altamira/2021/8.AGOSTO/ZONA POLICROMOS C.xlsx", m, divisiones, 'Agosto 2021',
                          minVariable, maxVariable)
HistogramaTsuavPolicromos("./altamira/2021/9. SEPTIEMBRE/ZONA POLICROMOS C.xlsx", m, divisiones, 'Septiembre 2021',
                          minVariable, maxVariable)
HistogramaTsuavPolicromos("./altamira/2021/10. OCTUBRE/ZONA POLICROMOS.xlsx", m, divisiones, 'Octubre 2021',
                          minVariable, maxVariable)
HistogramaTsuavPolicromos("./altamira/2021/11. NOVIEMBRE/ZONA POLICROMOS.xlsx", m, divisiones, 'Noviembre 2021',
                          minVariable, maxVariable)
HistogramaTsuavPolicromos("./altamira/2021/12. DICIEMBRE/ZONA POLICROMOS.xlsx", m, divisiones, 'Diciembre 2021',
                          minVariable, maxVariable)
#2022
HistogramaTsuavPolicromos("./altamira/2022/1.ENERO/ZONA POLICROMOS C.xlsx", m, divisiones, 'Enero 2022',
                          minVariable, maxVariable)
HistogramaTsuavPolicromos("./altamira/2022/2.FEBRERO/ZONA POLICROMOS C.xlsx", m, divisiones, 'Febrero 2022',
                          minVariable, maxVariable)
HistogramaTsuavPolicromos("./altamira/2022/3.MARZO/ZONA POLICROMOS C.xlsx", m, divisiones, 'Marzo 2022',
                          minVariable, maxVariable)
HistogramaTsuavPolicromos("./altamira/2022/4.ABRIL/ZONA POLICROMOS C.xlsx", m, divisiones, 'Abril 2022',
                          minVariable, maxVariable)
HistogramaTsuavPolicromos("./altamira/2022/5.MAYO/ZONA POLICROMOS.xlsx", m, divisiones, 'Mayo 2022',
                          minVariable, maxVariable)
HistogramaTsuavPolicromos("./altamira/2022/6. JUNIO/ZONA POLICROMOS C.xlsx", m, divisiones, 'Junio 2022',
                          minVariable, maxVariable)
HistogramaTsuavPolicromos("./altamira/2022/7.JULIO/ZONA POLICROMOS C.xlsx", m, divisiones, 'Julio 2022',
                          minVariable, maxVariable)
HistogramaTsuavPolicromos("./altamira/2022/8. AGOSTO/ZONA POLICROMOS C.xlsx", m, divisiones, 'Agosto 2022',
                          minVariable, maxVariable)
HistogramaTsuavPolicromos("./altamira/2022/9. SEPTIEMBRE/ZONA POLICROMOS C.xlsx", m, divisiones, 'Septiembre 2022',
                          minVariable, maxVariable)
HistogramaTsuavPolicromos("./altamira/2022/10. OCTUBRE/ZONA POLICROMOS C.xlsx", m, divisiones, 'Octubre 2022',
                          minVariable, maxVariable)
HistogramaTsuavPolicromos("./altamira/2022/11. NOVIEMBRE/ZONA POLICROMOS C.xlsx", m, divisiones, 'Noviembre 2022',
                          minVariable, maxVariable)
HistogramaTsuavPolicromos("./altamira/2022/12. DICIEMBRE/ZONA POLICROMOS.xlsx", m, divisiones, 'Diciembre 2022',
                          minVariable, maxVariable)

# %% [markdown]
# # 3. Histogramas de la cantidad de CO2 de Policromos sin suavizar
# ### Obtener la altura y anchura de los histogramas:

# %%
#Resetear las variables de referencia:
m=0 #Máximo de datos por columna hasta este momento
minVariable=100000000000#Minimo  para comparar de la variable a representar
maxVariable=0#Máximo para comparar de la variable a representar

# %%
2020
m, minVariable, maxVariable = AlturaCO2Policromos("./altamira/2020/10.OCTUBRE/ZONA POLICROMOS.xlsx",
                                                  m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Policromos("./altamira/2020/11.NOVIEMBRE/ZONA POLICROMOS C.xlsx",
                                                  m, divisiones,minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Policromos("./altamira/2020/12.DICIEMBRE/ZONA POLICROMOS C.xlsx",
                                                  m, divisiones,minVariable, maxVariable)
#2021
m, minVariable, maxVariable = AlturaCO2Policromos("./altamira/2021/1.ENERO/ZONA POLICROMOS ENERO.xlsx",
                                                  m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Policromos("./altamira/2021/2.FEBRERO/ZONA POLICROMOS C.xlsx",
                                                  m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Policromos("./altamira/2021/3.MARZO/ZONA POLICROMOS C.xlsx",
                                                  m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Policromos("./altamira/2021/4.ABRIL/ZONA POLICROMOS C.xlsx",
                                                  m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Policromos("./altamira/2021/5.MAYO/ZONA POLICROMOS C.xlsx",
                                                  m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Policromos("./altamira/2021/6.JUNIO/ZONA POLICROMOS C.xlsx",
                                                  m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Policromos("./altamira/2021/7.JULIO/ZONA POLICROMOS C.xlsx",
                                                  m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Policromos("./altamira/2021/8.AGOSTO/ZONA POLICROMOS C.xlsx",
                                                  m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Policromos("./altamira/2021/9. SEPTIEMBRE/ZONA POLICROMOS C.xlsx",
                                                  m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Policromos("./altamira/2021/10. OCTUBRE/ZONA POLICROMOS.xlsx",
                                                  m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Policromos("./altamira/2021/11. NOVIEMBRE/ZONA POLICROMOS.xlsx",
                                                  m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Policromos("./altamira/2021/12. DICIEMBRE/ZONA POLICROMOS.xlsx",
                                                  m, divisiones, minVariable, maxVariable)
#2022
m, minVariable, maxVariable = AlturaCO2Policromos("./altamira/2022/1.ENERO/ZONA POLICROMOS C.xlsx",
                                                  m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Policromos("./altamira/2022/2.FEBRERO/ZONA POLICROMOS C.xlsx",
                                                  m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Policromos("./altamira/2022/3.MARZO/ZONA POLICROMOS C.xlsx",
                                                  m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Policromos("./altamira/2022/4.ABRIL/ZONA POLICROMOS C.xlsx",
                                                  m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Policromos("./altamira/2022/5.MAYO/ZONA POLICROMOS.xlsx",
                                                  m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Policromos("./altamira/2022/6. JUNIO/ZONA POLICROMOS C.xlsx",
                                                  m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Policromos("./altamira/2022/7.JULIO/ZONA POLICROMOS C.xlsx",
                                                  m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Policromos("./altamira/2022/8. AGOSTO/ZONA POLICROMOS C.xlsx",
                                                  m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Policromos("./altamira/2022/9. SEPTIEMBRE/ZONA POLICROMOS C.xlsx",
                                                  m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Policromos("./altamira/2022/10. OCTUBRE/ZONA POLICROMOS C.xlsx",
                                                  m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Policromos("./altamira/2022/11. NOVIEMBRE/ZONA POLICROMOS C.xlsx",
                                                  m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2Policromos("./altamira/2022/12. DICIEMBRE/ZONA POLICROMOS.xlsx",
                                                  m, divisiones, minVariable, maxVariable)

# %% [markdown]
# ### Representar histogramas

# %%
# 2020
HistogramaCO2Policromos("./altamira/2020/10.OCTUBRE/ZONA POLICROMOS.xlsx", m, divisiones,
                        'Octubre 2020', minVariable, maxVariable)
HistogramaCO2Policromos("./altamira/2020/11.NOVIEMBRE/ZONA POLICROMOS C.xlsx", m, divisiones,
                        'Noviembre 2020', minVariable, maxVariable)
HistogramaCO2Policromos("./altamira/2020/12.DICIEMBRE/ZONA POLICROMOS C.xlsx", m, divisiones,
                        'Diciembre 2020', minVariable, maxVariable)
#2021
HistogramaCO2Policromos("./altamira/2021/1.ENERO/ZONA POLICROMOS ENERO.xlsx", m, divisiones,
                        'Enero 2021', minVariable, maxVariable)
HistogramaCO2Policromos("./altamira/2021/2.FEBRERO/ZONA POLICROMOS C.xlsx", m, divisiones,
                        'Febrero 2021', minVariable, maxVariable)
HistogramaCO2Policromos("./altamira/2021/3.MARZO/ZONA POLICROMOS C.xlsx", m, divisiones,
                        'Marzo 2021', minVariable, maxVariable)
HistogramaCO2Policromos("./altamira/2021/4.ABRIL/ZONA POLICROMOS C.xlsx", m, divisiones,
                        'Abril 2021', minVariable, maxVariable)
HistogramaCO2Policromos("./altamira/2021/5.MAYO/ZONA POLICROMOS C.xlsx", m, divisiones,
                        'Mayo 2021', minVariable, maxVariable)
HistogramaCO2Policromos("./altamira/2021/6.JUNIO/ZONA POLICROMOS C.xlsx", m, divisiones,
                        'Junio 2021', minVariable, maxVariable)
HistogramaCO2Policromos("./altamira/2021/7.JULIO/ZONA POLICROMOS C.xlsx", m, divisiones,
                        'Julio 2021', minVariable, maxVariable)
HistogramaCO2Policromos("./altamira/2021/8.AGOSTO/ZONA POLICROMOS C.xlsx", m, divisiones,
                        'Agosto 2021', minVariable, maxVariable)
HistogramaCO2Policromos("./altamira/2021/9. SEPTIEMBRE/ZONA POLICROMOS C.xlsx", m, divisiones,
                        'Septiembre 2021', minVariable, maxVariable)
HistogramaCO2Policromos("./altamira/2021/10. OCTUBRE/ZONA POLICROMOS.xlsx", m, divisiones,
                        'Octubre 2021', minVariable, maxVariable)
HistogramaCO2Policromos("./altamira/2021/11. NOVIEMBRE/ZONA POLICROMOS.xlsx", m, divisiones,
                        'Noviembre 2021', minVariable, maxVariable)
HistogramaCO2Policromos("./altamira/2021/12. DICIEMBRE/ZONA POLICROMOS.xlsx", m, divisiones,
                        'Diciembre 2021', minVariable, maxVariable)
#2022
HistogramaCO2Policromos("./altamira/2022/1.ENERO/ZONA POLICROMOS C.xlsx", m, divisiones,
                        'Enero 2022', minVariable, maxVariable)
HistogramaCO2Policromos("./altamira/2022/2.FEBRERO/ZONA POLICROMOS C.xlsx", m, divisiones,
                        'Febrero 2022', minVariable, maxVariable)
HistogramaCO2Policromos("./altamira/2022/3.MARZO/ZONA POLICROMOS C.xlsx", m, divisiones,
                        'Marzo 2022', minVariable, maxVariable)
HistogramaCO2Policromos("./altamira/2022/4.ABRIL/ZONA POLICROMOS C.xlsx", m, divisiones,
                        'Abril 2022', minVariable, maxVariable)
HistogramaCO2Policromos("./altamira/2022/5.MAYO/ZONA POLICROMOS.xlsx", m, divisiones,
                        'Mayo 2022', minVariable, maxVariable)
HistogramaCO2Policromos("./altamira/2022/6. JUNIO/ZONA POLICROMOS C.xlsx", m, divisiones,
                        'Junio 2022', minVariable, maxVariable)
HistogramaCO2Policromos("./altamira/2022/7.JULIO/ZONA POLICROMOS C.xlsx", m, divisiones,
                        'Julio 2022', minVariable, maxVariable)
HistogramaCO2Policromos("./altamira/2022/8. AGOSTO/ZONA POLICROMOS C.xlsx", m, divisiones,
                        'Agosto 2022', minVariable, maxVariable)
HistogramaCO2Policromos("./altamira/2022/9. SEPTIEMBRE/ZONA POLICROMOS C.xlsx", m, divisiones,
                        'Septiembre 2022', minVariable, maxVariable)
HistogramaCO2Policromos("./altamira/2022/10. OCTUBRE/ZONA POLICROMOS C.xlsx", m, divisiones,
                        'Octubre 2022', minVariable, maxVariable)
HistogramaCO2Policromos("./altamira/2022/11. NOVIEMBRE/ZONA POLICROMOS C.xlsx", m, divisiones,
                        'Noviembre 2022', minVariable, maxVariable)
HistogramaCO2Policromos("./altamira/2022/12. DICIEMBRE/ZONA POLICROMOS.xlsx", m, divisiones,
                        'Diciembre 2022', minVariable, maxVariable)

# %% [markdown]
# # 4. Histogramas de la cantidad de CO2 de Policromos suavizada
# ### Obtener la altura y anchura de los histogramas:

# %%
#Resetear las variables de referencia:
m=0 #Máximo de datos por columna hasta este momento
minVariable=100000000000#Minimo  para comparar de la variable a representar
maxVariable=0#Máximo para comparar de la variable a representar

# %%
2020
m, minVariable, maxVariable = AlturaCO2suavPolicromos("./altamira/2020/10.OCTUBRE/ZONA POLICROMOS.xlsx",
                                                      m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavPolicromos("./altamira/2020/11.NOVIEMBRE/ZONA POLICROMOS C.xlsx",
                                                      m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavPolicromos("./altamira/2020/12.DICIEMBRE/ZONA POLICROMOS C.xlsx",
                                                      m, divisiones, minVariable, maxVariable)
#2021
m, minVariable, maxVariable = AlturaCO2suavPolicromos("./altamira/2021/1.ENERO/ZONA POLICROMOS ENERO.xlsx",
                                                      m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavPolicromos("./altamira/2021/2.FEBRERO/ZONA POLICROMOS C.xlsx",
                                                      m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavPolicromos("./altamira/2021/3.MARZO/ZONA POLICROMOS C.xlsx",
                                                      m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavPolicromos("./altamira/2021/4.ABRIL/ZONA POLICROMOS C.xlsx",
                                                      m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavPolicromos("./altamira/2021/5.MAYO/ZONA POLICROMOS C.xlsx",
                                                      m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavPolicromos("./altamira/2021/6.JUNIO/ZONA POLICROMOS C.xlsx",
                                                      m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavPolicromos("./altamira/2021/7.JULIO/ZONA POLICROMOS C.xlsx",
                                                      m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavPolicromos("./altamira/2021/8.AGOSTO/ZONA POLICROMOS C.xlsx",
                                                      m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavPolicromos("./altamira/2021/9. SEPTIEMBRE/ZONA POLICROMOS C.xlsx",
                                                      m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavPolicromos("./altamira/2021/10. OCTUBRE/ZONA POLICROMOS.xlsx",
                                                      m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavPolicromos("./altamira/2021/11. NOVIEMBRE/ZONA POLICROMOS.xlsx",
                                                      m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavPolicromos("./altamira/2021/12. DICIEMBRE/ZONA POLICROMOS.xlsx",
                                                      m, divisiones, minVariable, maxVariable)
#2022
m, minVariable, maxVariable = AlturaCO2suavPolicromos("./altamira/2022/1.ENERO/ZONA POLICROMOS C.xlsx",
                                                      m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavPolicromos("./altamira/2022/2.FEBRERO/ZONA POLICROMOS C.xlsx",
                                                      m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavPolicromos("./altamira/2022/3.MARZO/ZONA POLICROMOS C.xlsx",
                                                      m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavPolicromos("./altamira/2022/4.ABRIL/ZONA POLICROMOS C.xlsx",
                                                      m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavPolicromos("./altamira/2022/5.MAYO/ZONA POLICROMOS.xlsx",
                                                      m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavPolicromos("./altamira/2022/6. JUNIO/ZONA POLICROMOS C.xlsx",
                                                      m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavPolicromos("./altamira/2022/7.JULIO/ZONA POLICROMOS C.xlsx",
                                                      m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavPolicromos("./altamira/2022/8. AGOSTO/ZONA POLICROMOS C.xlsx",
                                                      m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavPolicromos("./altamira/2022/9. SEPTIEMBRE/ZONA POLICROMOS C.xlsx",
                                                      m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavPolicromos("./altamira/2022/10. OCTUBRE/ZONA POLICROMOS C.xlsx",
                                                      m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavPolicromos("./altamira/2022/11. NOVIEMBRE/ZONA POLICROMOS C.xlsx",
                                                      m, divisiones, minVariable, maxVariable)
m, minVariable, maxVariable = AlturaCO2suavPolicromos("./altamira/2022/12. DICIEMBRE/ZONA POLICROMOS.xlsx",
                                                      m, divisiones, minVariable, maxVariable)

# %% [markdown]
# ### Representar histogramas

# %%
# 2020
HistogramaCO2suavPolicromos("./altamira/2020/10.OCTUBRE/ZONA POLICROMOS.xlsx", m, divisiones,
                            'Octubre 2020', minVariable, maxVariable)
HistogramaCO2suavPolicromos("./altamira/2020/11.NOVIEMBRE/ZONA POLICROMOS C.xlsx", m, divisiones,
                            'Noviembre 2020', minVariable, maxVariable)
HistogramaCO2suavPolicromos("./altamira/2020/12.DICIEMBRE/ZONA POLICROMOS C.xlsx", m, divisiones,
                            'Diciembre 2020', minVariable, maxVariable)
#2021
HistogramaCO2suavPolicromos("./altamira/2021/1.ENERO/ZONA POLICROMOS ENERO.xlsx", m, divisiones,
                            'Enero 2021', minVariable, maxVariable)
HistogramaCO2suavPolicromos("./altamira/2021/2.FEBRERO/ZONA POLICROMOS C.xlsx", m, divisiones,
                            'Febrero 2021', minVariable, maxVariable)
HistogramaCO2suavPolicromos("./altamira/2021/3.MARZO/ZONA POLICROMOS C.xlsx", m, divisiones,
                            'Marzo 2021', minVariable, maxVariable)
HistogramaCO2suavPolicromos("./altamira/2021/4.ABRIL/ZONA POLICROMOS C.xlsx", m, divisiones,
                            'Abril 2021', minVariable, maxVariable)
HistogramaCO2suavPolicromos("./altamira/2021/5.MAYO/ZONA POLICROMOS C.xlsx", m, divisiones,
                            'Mayo 2021', minVariable, maxVariable)
HistogramaCO2suavPolicromos("./altamira/2021/6.JUNIO/ZONA POLICROMOS C.xlsx", m, divisiones,
                            'Junio 2021', minVariable, maxVariable)
HistogramaCO2suavPolicromos("./altamira/2021/7.JULIO/ZONA POLICROMOS C.xlsx", m, divisiones,
                            'Julio 2021', minVariable, maxVariable)
HistogramaCO2suavPolicromos("./altamira/2021/8.AGOSTO/ZONA POLICROMOS C.xlsx", m, divisiones,
                            'Agosto 2021', minVariable, maxVariable)
HistogramaCO2suavPolicromos("./altamira/2021/9. SEPTIEMBRE/ZONA POLICROMOS C.xlsx", m, divisiones,
                            'Septiembre 2021', minVariable, maxVariable)
HistogramaCO2suavPolicromos("./altamira/2021/10. OCTUBRE/ZONA POLICROMOS.xlsx", m, divisiones,
                            'Octubre 2021', minVariable, maxVariable)
HistogramaCO2suavPolicromos("./altamira/2021/11. NOVIEMBRE/ZONA POLICROMOS.xlsx", m, divisiones,
                            'Noviembre 2021', minVariable, maxVariable)
HistogramaCO2suavPolicromos("./altamira/2021/12. DICIEMBRE/ZONA POLICROMOS.xlsx", m, divisiones,
                            'Diciembre 2021', minVariable, maxVariable)
#2022
HistogramaCO2suavPolicromos("./altamira/2022/1.ENERO/ZONA POLICROMOS C.xlsx", m, divisiones,
                            'Enero 2022', minVariable, maxVariable)
HistogramaCO2suavPolicromos("./altamira/2022/2.FEBRERO/ZONA POLICROMOS C.xlsx", m, divisiones,
                            'Febrero 2022', minVariable, maxVariable)
HistogramaCO2suavPolicromos("./altamira/2022/3.MARZO/ZONA POLICROMOS C.xlsx", m, divisiones,
                            'Marzo 2022', minVariable, maxVariable)
HistogramaCO2suavPolicromos("./altamira/2022/4.ABRIL/ZONA POLICROMOS C.xlsx", m, divisiones,
                            'Abril 2022', minVariable, maxVariable)
HistogramaCO2suavPolicromos("./altamira/2022/5.MAYO/ZONA POLICROMOS.xlsx", m, divisiones,
                            'Mayo 2022', minVariable, maxVariable)
HistogramaCO2suavPolicromos("./altamira/2022/6. JUNIO/ZONA POLICROMOS C.xlsx", m, divisiones,
                            'Junio 2022', minVariable, maxVariable)
HistogramaCO2suavPolicromos("./altamira/2022/7.JULIO/ZONA POLICROMOS C.xlsx", m, divisiones,
                            'Julio 2022', minVariable, maxVariable)
HistogramaCO2suavPolicromos("./altamira/2022/8. AGOSTO/ZONA POLICROMOS C.xlsx", m, divisiones,
                            'Agosto 2022', minVariable, maxVariable)
HistogramaCO2suavPolicromos("./altamira/2022/9. SEPTIEMBRE/ZONA POLICROMOS C.xlsx", m, divisiones,
                            'Septiembre 2022', minVariable, maxVariable)
HistogramaCO2suavPolicromos("./altamira/2022/10. OCTUBRE/ZONA POLICROMOS C.xlsx", m, divisiones,
                            'Octubre 2022', minVariable, maxVariable)
HistogramaCO2suavPolicromos("./altamira/2022/11. NOVIEMBRE/ZONA POLICROMOS C.xlsx", m, divisiones,
                            'Noviembre 2022', minVariable, maxVariable)
HistogramaCO2suavPolicromos("./altamira/2022/12. DICIEMBRE/ZONA POLICROMOS.xlsx", m, divisiones,
                            'Diciembre 2022', minVariable, maxVariable)
