# %%
#Imports
import pandas as pd
import numpy as np
from numpy import delete
import scipy.stats as stats

#Código necesario para correr funciones desde otro archivo .ipynb de la misma carpeta
# %run Preparar_datos.ipynb
# %run TablaResumenCC.ipynb

# %% [markdown]
# # Índice: Qué hay en el documento
# ¿Las ocilaciones llegan/vienen de policromos?
# - CCs sin suavizar de Tp-Th, Tp-Tc y Tp-Te
# - CCs con los datos suavizados de Tp-Th, Tp-Tc y Tp-Te

# %% [markdown]
# Significado de las abreviaturas:
#
# - CC: Coeficientes de correlación
# - Tc: Temperatura del Cruce (ºC)
# - Te: Temperatura del exterior (ºC)
# - Th: Temperatura de la entrada, también llamada Hall (ºC)
# - Tp: Temperatura de Policromos (ºC)

# %% [markdown]
# Solo obtener para los mese con oscilaciones claras:
# - 1) Los meses con oscilaciones claras para el C02 del cruce son:
#  Julio, agosto y septiembre de 2021.
#  Junio, julio, agosto y septiembre de 2022
# - 2) Los meses con oscilaciones claras para el CO2 del hall son:
# Julio, agosto, septiembre y octubre de 2021. Mayo, junio y julio de 2022

# %% [markdown]
# # 3.1) ¿Las ocilaciones llegan/vienen de policromos? Coef a partir de las temperaturas sin suavizar

# %% [markdown]
# ### Preparar datos:

# %%
###Entrada:
#Leer los datos
#2021
dfEntrada_6_21 = pd.read_excel("./altamira/2021/6.JUNIO/ZONA ENTRADA A.xlsx")
dfEntrada_7_21 = pd.read_excel("./altamira/2021/7.JULIO/ZONA ENTRADA A.xlsx")
dfEntrada_8_21 = pd.read_excel("./altamira/2021/8.AGOSTO/ZONA ENTRADA A.xlsx")
dfEntrada_9_21 = pd.read_excel("./altamira/2021/9. SEPTIEMBRE/ZONA ENTRADA A.xlsx")
dfEntrada_10_21 = pd.read_excel("./altamira/2021/10. OCTUBRE/ZONA ENTRADA A.xlsx")
#2022
dfEntrada_6_22 = pd.read_excel("./altamira/2022/6. JUNIO/ZONA ENTRADA.xlsx")
dfEntrada_7_22 = pd.read_excel("./altamira/2022/7.JULIO/ZONA ENTRADA A.xlsx")
dfEntrada_8_22 = pd.read_excel("./altamira/2022/8. AGOSTO/ZONA ENTRADA A.xlsx")
dfEntrada_9_22 = pd.read_excel("./altamira/2022/9. SEPTIEMBRE/ZONA ENTRADA A.xlsx")
dfEntrada_10_22 = pd.read_excel("./altamira/2022/10. OCTUBRE/ZONA ENTRADA A.xlsx")
#Unir df:
dfEntrada_21 = pd.concat([dfEntrada_6_21, dfEntrada_7_21, dfEntrada_8_21, dfEntrada_9_21, dfEntrada_10_21], axis=0)
dfEntrada_22 = pd.concat([dfEntrada_6_22, dfEntrada_7_22, dfEntrada_8_22, dfEntrada_9_22, dfEntrada_10_22], axis=0)

###Cruce:
#Leer los datos
#2021
dfCruce_6_21 = pd.read_excel("./altamira/2021/6.JUNIO/ZONA CRUCE D.xlsx")
dfCruce_7_21 = pd.read_excel("./altamira/2021/7.JULIO/ZONA CRUCE D.xlsx")
dfCruce_8_21 = pd.read_excel("./altamira/2021/8.AGOSTO/ZONA CRUCE D.xlsx")
dfCruce_9_21 = pd.read_excel("./altamira/2021/9. SEPTIEMBRE/ZONA CRUCE D.xlsx")
dfCruce_10_21 = pd.read_excel("./altamira/2021/10. OCTUBRE/ZONA CRUCE D.xlsx")
#2022
dfCruce_6_22 = pd.read_excel("./altamira/2022/6. JUNIO/ZONA CRUCE D.xlsx")
dfCruce_7_22 = pd.read_excel("./altamira/2022/7.JULIO/ZONA CRUCE C.xlsx")
dfCruce_8_22 = pd.read_excel("./altamira/2022/8. AGOSTO/ZONA CRUCE D.xlsx")
dfCruce_9_22 = pd.read_excel("./altamira/2022/9. SEPTIEMBRE/ZONA CRUCE D.xlsx")
dfCruce_10_22 = pd.read_excel("./altamira/2022/10. OCTUBRE/ZONA CRUCE D.xlsx")
#Unir df:
dfCruce_21 = pd.concat([dfCruce_6_21, dfCruce_7_21, dfCruce_8_21, dfCruce_9_21, dfCruce_10_21], axis=0)
dfCruce_22 = pd.concat([dfCruce_6_22, dfCruce_7_22, dfCruce_8_22, dfCruce_9_22, dfCruce_10_22], axis=0)

###Exterior:
#Leer los datos
#2021
dfExterior_6_21 = pd.read_excel("./altamira/2021/6.JUNIO/ZONA EXTERIOR.xlsx")
dfExterior_7_21 = pd.read_excel("./altamira/2021/7.JULIO/ZONA EXTERIOR.xlsx")
dfExterior_8_21 = pd.read_excel("./altamira/2021/8.AGOSTO/ZONA EXTERIOR.xlsx")
dfExterior_9_21 = pd.read_excel("./altamira/2021/9. SEPTIEMBRE/ZONA EXTERIOR.xlsx")
dfExterior_10_21 = pd.read_excel("./altamira/2021/10. OCTUBRE/ZONA EXTERIOR.xlsx")
#2022
dfExterior_6_22 = pd.read_excel("./altamira/2022/6. JUNIO/ZONA EXTERIOR.xlsx")
dfExterior_7_22 = pd.read_excel("./altamira/2022/7.JULIO/ZONA EXTERIOR.xlsx")
dfExterior_8_22 = pd.read_excel("./altamira/2022/8. AGOSTO/ZONA EXTERIOR.xlsx")
dfExterior_9_22 = pd.read_excel("./altamira/2022/9. SEPTIEMBRE/ZONA EXTERIOR.xlsx")
dfExterior_10_22 = pd.read_excel("./altamira/2022/10. OCTUBRE/ZONA EXTERIOR.xlsx")
#Unir df:
dfExterior_21 = pd.concat([dfExterior_6_21, dfExterior_7_21, dfExterior_8_21, dfExterior_9_21, dfExterior_10_21], axis=0)
dfExterior_22 = pd.concat([dfExterior_6_22, dfExterior_7_22, dfExterior_8_22, dfExterior_9_22, dfExterior_10_22], axis=0)

###Policromos:
#Leer los datos
#2021
dfPolicromos_6_21 = pd.read_excel("./altamira/2021/6.JUNIO/ZONA POLICROMOS C.xlsx")
dfPolicromos_7_21 = pd.read_excel("./altamira/2021/7.JULIO/ZONA POLICROMOS C.xlsx")
dfPolicromos_8_21 = pd.read_excel("./altamira/2021/8.AGOSTO/ZONA POLICROMOS C.xlsx")
dfPolicromos_9_21 = pd.read_excel("./altamira/2021/9. SEPTIEMBRE/ZONA POLICROMOS C.xlsx")
dfPolicromos_10_21 = pd.read_excel("./altamira/2021/10. OCTUBRE/ZONA POLICROMOS.xlsx")
#2022
dfPolicromos_6_22 = pd.read_excel("./altamira/2022/6. JUNIO/ZONA POLICROMOS C.xlsx")
dfPolicromos_7_22 = pd.read_excel("./altamira/2022/7.JULIO/ZONA POLICROMOS C.xlsx")
dfPolicromos_8_22 = pd.read_excel("./altamira/2022/8. AGOSTO/ZONA POLICROMOS C.xlsx")
dfPolicromos_9_22 = pd.read_excel("./altamira/2022/9. SEPTIEMBRE/ZONA POLICROMOS C.xlsx")
dfPolicromos_10_22 = pd.read_excel("./altamira/2022/10. OCTUBRE/ZONA POLICROMOS C.xlsx")
#Unir df:
dfPolicromos_21 = pd.concat([dfPolicromos_6_21, dfPolicromos_7_21, dfPolicromos_8_21, dfPolicromos_9_21, dfPolicromos_10_21], axis=0)
dfPolicromos_22 = pd.concat([dfPolicromos_6_22, dfPolicromos_7_22, dfPolicromos_8_22, dfPolicromos_9_22, dfPolicromos_10_22], axis=0)

#Resetear los índices de los df:
dfPolicromos_21= dfPolicromos_21.reset_index(drop=True)
dfPolicromos_22= dfPolicromos_22.reset_index(drop=True)
dfExterior_21= dfExterior_21.reset_index(drop=True)
dfExterior_22= dfExterior_22.reset_index(drop=True)
dfCruce_21= dfCruce_21.reset_index(drop=True)
dfCruce_22= dfCruce_22.reset_index(drop=True)
dfEntrada_21= dfEntrada_21.reset_index(drop=True)
dfEntrada_22= dfEntrada_22.reset_index(drop=True)

#Guardar df  en archivos excel:
dfCruce_21.to_excel('./DatosDeInteresPorSalasYAños/Cruce21.xlsx')
dfCruce_22.to_excel('./DatosDeInteresPorSalasYAños/Cruce22.xlsx')
dfExterior_21.to_excel('./DatosDeInteresPorSalasYAños/Exterior21.xlsx')
dfExterior_22.to_excel('./DatosDeInteresPorSalasYAños/Exterior22.xlsx')
dfEntrada_21.to_excel('./DatosDeInteresPorSalasYAños/Hall21.xlsx')
dfEntrada_22.to_excel('./DatosDeInteresPorSalasYAños/Hall22.xlsx')
dfPolicromos_21.to_excel('./DatosDeInteresPorSalasYAños/Policromos21.xlsx')
dfPolicromos_22.to_excel('./DatosDeInteresPorSalasYAños/Policromos22.xlsx')

# Datos cada 15 mins Policromos de los archivos unidos:
DatosPolicromos_21 = adaptar_len_policromos('./DatosDeInteresPorSalasYAños/Cruce21.xlsx',
                                            './DatosDeInteresPorSalasYAños/Exterior21.xlsx',
                                            './DatosDeInteresPorSalasYAños/Hall21.xlsx',
                                            './DatosDeInteresPorSalasYAños/Policromos21.xlsx','2021')
DatosPolicromos_22 = adaptar_len_policromos('./DatosDeInteresPorSalasYAños/Cruce22.xlsx',
                                            './DatosDeInteresPorSalasYAños/Exterior22.xlsx',
                                            './DatosDeInteresPorSalasYAños/Hall22.xlsx',
                                            './DatosDeInteresPorSalasYAños/Policromos22.xlsx', '2022')
#Separar por semanas:
SemanaCruce21 = SepararPorSemanas('./DatosDeInteresPorSalasYAños/Cruce21.xlsx')
SemanaCruce22 = SepararPorSemanas('./DatosDeInteresPorSalasYAños/Cruce22.xlsx')
SemanaExterior21 = SepararPorSemanas('./DatosDeInteresPorSalasYAños/Exterior21.xlsx')
SemanaExterior22 = SepararPorSemanas('./DatosDeInteresPorSalasYAños/Exterior22.xlsx')
SemanaHall21 = SepararPorSemanas('./DatosDeInteresPorSalasYAños/Hall21.xlsx')
SemanaHall22 = SepararPorSemanas('./DatosDeInteresPorSalasYAños/Hall22.xlsx')
PolicromosSemanas_2021 = separar_policromos_semanas(DatosPolicromos_21)
PolicromosSemanas_2022 = separar_policromos_semanas(DatosPolicromos_22)

##Arreglar los problemas en los datos por semanas: 
#Semana 8 de 2021:
PolicromosSemanas_2021[8+4]=PolicromosSemanas_2021[8+4][:339]
#Semana 9 de 2021:
PolicromosSemanas_2021[9+4]=PolicromosSemanas_2021[9+4][192:]
PolicromosSemanas_2021[9+4]=PolicromosSemanas_2021[9+4].reset_index(drop=True)

#semana 0+4 de 2022?
PolicromosSemanas_2022[4]=PolicromosSemanas_2022[4].drop([384,385],axis=0)
SemanaExterior22[4]=SemanaExterior22[4].drop([385],axis=0)
PolicromosSemanas_2022[4]= PolicromosSemanas_2022[4].reset_index(drop=True)
SemanaExterior22[4]= SemanaExterior22[4].reset_index(drop=True)

#Semana 4+4 de 2022:
SemanaHall22[4+4]=SemanaHall22[4+4][:669]
SemanaCruce22[4+4]=SemanaCruce22[4+4][:669]
PolicromosSemanas_2022[4+4]=PolicromosSemanas_2022[4+4][:669]

# %% [markdown]
# ### Obtener coeficientes:

# %%
#Función adaptada para variables sin suavizar
def cc_Th_Tc_Te_Tp(DataframeCruce, DataframeExterior, DataframeHall, DatosPolicromos):
    """
    Atributos:
    1) DataframeCruce: Lista de dataframes por semanas correspondiente a los datos de un mes de Cruce
    2) DataframeExterior: Lista de dataframes por semanas correspondiente a los datos de un mes de Exterior
    3) DataframeHall: Lista de dataframes por semanas correspondiente a los datos de un mes de Hall
    4) DatosPolicromos: Lista de dataframes por semanas correspondiente a los datos de un mes de Policromos
    
    Devuelve:
    Una lista de listas, r. Cada elemento de r, r[i] con i=0, 1, 2, 3, 4, es una lista con los coeficiente de correlación y p 
    valores correspondientes a una semana.  r[i] = r_Tp_Th, p_Tp_Th, r_Tp_Tc, p_Tp_Tc, r_Tp_Te, p_Tp_Te
    
    ¿A qué corresponde cada elemento de r[i]?
    1) r_Tp_Th: Coeficiente de correlación entre la temperatura de Policromos y del Hall
    2) p_Tp_Th: P-valor correspondiente a r_Tp_Th
    3) r_Tp_Tc: Coeficiente de correlación entre la temperatura de Policromos y del Cruce
    4) p_Tp_Tc: P-valor correspondiente a r_Tp_Tc
    5) r_Tp_Te: Coeficiente de correlación entre la temperatura de Policromos y la exterior
    6) p_Tp_Te: P-valor correspondiente a r_Tp_Te
    """
    i=0
    r=[]
    while i<len(DataframeCruce):
       #print(i)
        DataframeCruce[i].reset_index(drop=True, inplace=True)
        DataframeExterior[i].reset_index(drop=True, inplace=True)
        DataframeHall[i].reset_index(drop=True, inplace=True)
        DatosPolicromos[i].reset_index(drop=True, inplace=True)
        
        # Variables que me van a hacer falta: Tp_Th, Tp_Tc, Tp_Te
        if  DataframeCruce[i]["Temperatura D (° C)"].isna().all() :
#             print('No datos en cruce')
            for index, _ in DataframeExterior[i].iterrows():#Se va fuera de indice
                if  __builtins__.sum([pd.isna(DataframeHall[i]['Temperatura A (° C)'][index]),
                                      pd.isna(DataframeExterior[i]["Tr Exterior (C Tr)"][index]),
                                      pd.isna(DatosPolicromos[i]['Tp'][index])]) > 0:
#                     DataframeCruce[i].drop([index], axis=0, inplace=True)
                    DataframeExterior[i].drop([index], axis=0, inplace=True)
                    DataframeHall[i].drop([index], axis=0, inplace=True)
                    DatosPolicromos[i].drop([index], axis=0, inplace=True)

            #Mediante scipy por semanas:
            r_Tp_Th, p_Tp_Th = stats.pearsonr(DatosPolicromos[i]['Tp'], DataframeHall[i]['Temperatura A (° C)'])
#             r_Tp_Tc, p_Tp_Tc = stats.pearsonr(DatosPolicromos[i]['Tp'], DataframeCruce[i]["Temperatura D (° C)"])
            r_Tp_Te, p_Tp_Te = stats.pearsonr(DatosPolicromos[i]['Tp'], DataframeExterior[i]["Tr Exterior (C Tr)"])
            rs = r_Tp_Th, p_Tp_Th, np.nan,  np.nan, r_Tp_Te, p_Tp_Te, len(DatosPolicromos[i]['Tp'])
        
        else:
#             print('si datos en cruce')
            for index, _ in DataframeExterior[i].iterrows():#Se va fuera de indice
                if  __builtins__.sum([pd.isna(DataframeCruce[i]["Temperatura D (° C)"][index]),
                                      pd.isna(DataframeHall[i]['Temperatura A (° C)'][index]),
                                      pd.isna(DataframeExterior[i]["Tr Exterior (C Tr)"][index]),
                                      pd.isna(DatosPolicromos[i]['Tp'][index])]) > 0:
                    DataframeCruce[i].drop([index], axis=0, inplace=True)
                    DataframeExterior[i].drop([index], axis=0, inplace=True)
                    DataframeHall[i].drop([index], axis=0, inplace=True)
                    DatosPolicromos[i].drop([index], axis=0, inplace=True)

            #Mediante scipy por semanas:
            r_Tp_Th, p_Tp_Th = stats.pearsonr(DatosPolicromos[i]['Tp'], DataframeHall[i]['Temperatura A (° C)'])
            r_Tp_Tc, p_Tp_Tc = stats.pearsonr(DatosPolicromos[i]['Tp'], DataframeCruce[i]["Temperatura D (° C)"])
            r_Tp_Te, p_Tp_Te = stats.pearsonr(DatosPolicromos[i]['Tp'], DataframeExterior[i]["Tr Exterior (C Tr)"])
            rs = r_Tp_Th, p_Tp_Th, r_Tp_Tc, p_Tp_Tc, r_Tp_Te, p_Tp_Te, len(DatosPolicromos[i]['Tp'])
        r.append(rs)
        i=i+1
    return(r)

# %%
cc21 = cc_Th_Tc_Te_Tp(SemanaCruce21, SemanaExterior21, SemanaHall21, PolicromosSemanas_2021)
cc22 = cc_Th_Tc_Te_Tp(SemanaCruce22, SemanaExterior22, SemanaHall22, PolicromosSemanas_2022)

# %%
s1=pd.Series([cc21[0][0], cc21[1][0],cc21[2][0],cc21[3][0],cc21[4][0],cc21[5][0],cc21[6][0],cc21[7][0],cc21[8][0],cc21[9][0],
              cc21[10][0], cc21[11][0], cc21[12][0], cc21[13][0], cc21[14][0], cc21[15][0], cc21[16][0], cc21[17][0],
              cc21[18][0],cc21[19][0],cc21[20][0],cc21[21][0],
              cc22[0][0], cc22[1][0],cc22[2][0],cc22[3][0],cc22[4][0],cc22[5][0],cc22[6][0],cc22[7][0],cc22[8][0],
              cc22[9][0], cc22[10][0], cc22[11][0], cc22[12][0], cc22[13][0], cc22[14][0], cc22[15][0], cc22[16][0],
              cc22[17][0], cc22[18][0], cc22[19][0], cc22[20][0], cc22[21][0], cc22[22][0]],
            index = ['Sem0 2021','Sem1 2021','Sem2 2021','Sem3 2021','Sem4 2021','Sem5 2021','Sem6 2021','Sem7 2021','Sem8 2021',
                    'Sem9 2021','Sem10 2021','Sem11 2021','Sem12 2021','Sem13 2021','Sem14 2021','Sem15 2021','Sem 16 2021',
                    'Sem 17 2021','Sem 18 2021','Sem 19 2021','Sem 20 2021','Sem 21 2021',
                    'Sem0 2022','Sem1 2022','Sem2 2022','Sem3 2022','Sem4 2022','Sem5 2022','Sem6 2022','Sem7 2022','Sem8 2021',
                    'Sem9 2022','Sem10 2022','Sem11 2022','Sem12 2022','Sem13 2022','Sem14 2022','Sem15 2022','Sem16 2022',
                    'Sem17 2022','Sem18 2022','Sem19 2022','Sem20 2022','Sem21 2022','Sem22 2022'])
s2=pd.Series([cc21[0][1], cc21[1][1],cc21[2][1],cc21[3][1],cc21[4][1],cc21[5][1],cc21[6][1],cc21[7][1],cc21[8][1],cc21[9][1],
              cc21[10][1], cc21[11][1], cc21[12][1], cc21[13][1], cc21[14][1], cc21[15][1], cc21[16][1], cc21[17][1], 
              cc21[18][1],cc21[19][1],cc21[20][1],cc21[21][1],
              cc22[0][1], cc22[1][1],cc22[2][1],cc22[3][1],cc22[4][1],cc22[5][1],cc22[6][1],cc22[7][1],cc22[8][1],
              cc22[9][1], cc22[10][1], cc22[11][1], cc22[12][1], cc22[13][1], cc22[14][1], cc22[15][1], cc22[16][1],
              cc22[17][1], cc22[18][1], cc22[19][1], cc22[20][1], cc22[21][1], cc22[22][1]],
            index = ['Sem0 2021','Sem1 2021','Sem2 2021','Sem3 2021','Sem4 2021','Sem5 2021','Sem6 2021','Sem7 2021','Sem8 2021',
                    'Sem9 2021','Sem10 2021','Sem11 2021','Sem12 2021','Sem13 2021','Sem14 2021','Sem15 2021','Sem 16 2021',
                    'Sem 17 2021','Sem 18 2021','Sem 19 2021','Sem 20 2021','Sem 21 2021',
                    'Sem0 2022','Sem1 2022','Sem2 2022','Sem3 2022','Sem4 2022','Sem5 2022','Sem6 2022','Sem7 2022','Sem8 2021',
                    'Sem9 2022','Sem10 2022','Sem11 2022','Sem12 2022','Sem13 2022','Sem14 2022','Sem15 2022','Sem16 2022',
                    'Sem17 2022','Sem18 2022','Sem19 2022','Sem20 2022','Sem21 2022','Sem22 2022'])
s3=pd.Series([cc21[0][2], cc21[1][2],cc21[2][2],cc21[3][2],cc21[4][2],cc21[5][2],cc21[6][2],cc21[7][2],cc21[8][2],cc21[9][2],
              cc21[10][2], cc21[11][2], cc21[12][2], cc21[13][2], cc21[14][2], cc21[15][2], cc21[16][2], cc21[17][2],
              cc21[18][2],cc21[19][2],cc21[20][2],cc21[21][2], 
              cc22[0][2], cc22[1][2],cc22[2][2],cc22[3][2],cc22[4][2],cc22[5][2],cc22[6][2],cc22[7][2],cc22[8][2],
              cc22[9][2], cc22[10][2], cc22[11][2], cc22[12][2], cc22[13][2], cc22[14][2], cc22[15][2], cc22[16][2],
              cc22[17][2], cc22[18][2], cc22[19][2], cc22[20][2], cc22[21][2], cc22[22][2]],
            index = ['Sem0 2021','Sem1 2021','Sem2 2021','Sem3 2021','Sem4 2021','Sem5 2021','Sem6 2021','Sem7 2021','Sem8 2021',
                    'Sem9 2021','Sem10 2021','Sem11 2021','Sem12 2021','Sem13 2021','Sem14 2021','Sem15 2021','Sem 16 2021',
                    'Sem 17 2021','Sem 18 2021','Sem 19 2021','Sem 20 2021','Sem 21 2021',
                    'Sem0 2022','Sem1 2022','Sem2 2022','Sem3 2022','Sem4 2022','Sem5 2022','Sem6 2022','Sem7 2022','Sem8 2021',
                    'Sem9 2022','Sem10 2022','Sem11 2022','Sem12 2022','Sem13 2022','Sem14 2022','Sem15 2022','Sem16 2022',
                    'Sem17 2022','Sem18 2022','Sem19 2022','Sem20 2022','Sem21 2022','Sem22 2022'])
s4=pd.Series([cc21[0][3], cc21[1][3],cc21[2][3],cc21[3][3],cc21[4][3],cc21[5][3],cc21[6][3],cc21[7][3],cc21[8][3],cc21[9][3],
              cc21[10][3], cc21[11][3], cc21[12][3], cc21[13][3], cc21[14][3], cc21[15][3], cc21[16][3], cc21[17][3],
              cc21[18][3],cc21[19][3],cc21[20][3],cc21[21][3],
              cc22[0][3], cc22[1][3],cc22[2][3],cc22[3][3],cc22[4][3],cc22[5][3],cc22[6][3],cc22[7][3],cc22[8][3],
              cc22[9][3], cc22[10][3], cc22[11][3], cc22[12][3], cc22[13][3], cc22[14][3], cc22[15][3], cc22[16][3],
              cc22[17][3], cc22[18][3], cc22[19][3], cc22[20][3], cc22[21][3], cc22[22][3]],
            index = ['Sem0 2021','Sem1 2021','Sem2 2021','Sem3 2021','Sem4 2021','Sem5 2021','Sem6 2021','Sem7 2021','Sem8 2021',
                    'Sem9 2021','Sem10 2021','Sem11 2021','Sem12 2021','Sem13 2021','Sem14 2021','Sem15 2021','Sem 16 2021',
                    'Sem 17 2021','Sem 18 2021','Sem 19 2021','Sem 20 2021','Sem 21 2021',
                    'Sem0 2022','Sem1 2022','Sem2 2022','Sem3 2022','Sem4 2022','Sem5 2022','Sem6 2022','Sem7 2022','Sem8 2021',
                    'Sem9 2022','Sem10 2022','Sem11 2022','Sem12 2022','Sem13 2022','Sem14 2022','Sem15 2022','Sem16 2022',
                    'Sem17 2022','Sem18 2022','Sem19 2022','Sem20 2022','Sem21 2022','Sem22 2022'])
s5=pd.Series([cc21[0][4], cc21[1][4],cc21[2][4],cc21[3][4],cc21[4][4],cc21[5][4],cc21[6][4],cc21[7][4],cc21[8][4],cc21[9][4],
              cc21[10][4], cc21[11][4], cc21[12][4], cc21[13][4], cc21[14][4], cc21[15][4], cc21[16][4], cc21[17][4], 
              cc21[18][4],cc21[19][4],cc21[20][4],cc21[21][4],
              cc22[0][4], cc22[1][4],cc22[2][4],cc22[3][4],cc22[4][4],cc22[5][4],cc22[6][4],cc22[7][4],cc22[8][4],
              cc22[9][4], cc22[10][4], cc22[11][4], cc22[12][4], cc22[13][4], cc22[14][4], cc22[15][0], cc22[16][4],
              cc22[17][4], cc22[18][4], cc22[19][4], cc22[20][4], cc22[21][4], cc22[22][4]],
            index = ['Sem0 2021','Sem1 2021','Sem2 2021','Sem3 2021','Sem4 2021','Sem5 2021','Sem6 2021','Sem7 2021','Sem8 2021',
                    'Sem9 2021','Sem10 2021','Sem11 2021','Sem12 2021','Sem13 2021','Sem14 2021','Sem15 2021','Sem 16 2021',
                    'Sem 17 2021','Sem 18 2021','Sem 19 2021','Sem 20 2021','Sem 21 2021',
                    'Sem0 2022','Sem1 2022','Sem2 2022','Sem3 2022','Sem4 2022','Sem5 2022','Sem6 2022','Sem7 2022','Sem8 2021',
                    'Sem9 2022','Sem10 2022','Sem11 2022','Sem12 2022','Sem13 2022','Sem14 2022','Sem15 2022','Sem16 2022',
                    'Sem17 2022','Sem18 2022','Sem19 2022','Sem20 2022','Sem21 2022','Sem22 2022'])
s6=pd.Series([cc21[0][5], cc21[1][5],cc21[2][5],cc21[3][5],cc21[4][5],cc21[5][5],cc21[6][5],cc21[7][5],cc21[8][5],cc21[9][5],
              cc21[10][5], cc21[11][5], cc21[12][5], cc21[13][5], cc21[14][5], cc21[15][5], cc21[16][5], cc21[17][5], 
              cc21[18][5],cc21[19][5],cc21[20][5],cc21[21][5],
              cc22[0][5], cc22[1][5],cc22[2][5],cc22[3][5],cc22[4][5],cc22[5][5],cc22[6][5],cc22[7][5],cc22[8][5],
              cc22[9][5], cc22[10][5], cc22[11][5], cc22[12][5], cc22[13][5], cc22[14][5], cc22[15][5], cc22[16][5],
              cc22[17][5], cc22[18][5], cc22[19][5], cc22[20][5], cc22[21][5], cc22[22][5]],
            index = ['Sem0 2021','Sem1 2021','Sem2 2021','Sem3 2021','Sem4 2021','Sem5 2021','Sem6 2021','Sem7 2021','Sem8 2021',
                    'Sem9 2021','Sem10 2021','Sem11 2021','Sem12 2021','Sem13 2021','Sem14 2021','Sem15 2021','Sem 16 2021',
                    'Sem 17 2021','Sem 18 2021','Sem 19 2021','Sem 20 2021','Sem 21 2021',
                    'Sem0 2022','Sem1 2022','Sem2 2022','Sem3 2022','Sem4 2022','Sem5 2022','Sem6 2022','Sem7 2022','Sem8 2021',
                    'Sem9 2022','Sem10 2022','Sem11 2022','Sem12 2022','Sem13 2022','Sem14 2022','Sem15 2022','Sem16 2022',
                    'Sem17 2022','Sem18 2022','Sem19 2022','Sem20 2022','Sem21 2022','Sem22 2022'])
s7=pd.Series([cc21[0][6], cc21[1][6],cc21[2][6],cc21[3][6],cc21[4][6],cc21[5][6],cc21[6][6],cc21[7][6],cc21[8][6],cc21[9][6],
              cc21[10][6], cc21[11][6], cc21[12][6], cc21[13][6], cc21[14][6], cc21[15][6], cc21[16][6], cc21[17][6], 
              cc21[18][6],cc21[19][6],cc21[20][6],cc21[21][6],
              cc22[0][6], cc22[1][6],cc22[2][6],cc22[3][6],cc22[4][6],cc22[5][6],cc22[6][6],cc22[7][6],cc22[8][6],
              cc22[9][6], cc22[10][6], cc22[11][6], cc22[12][6], cc22[13][6], cc22[14][6], cc22[15][6], cc22[16][6],
              cc22[17][6], cc22[18][6], cc22[19][6], cc22[20][6], cc22[21][6], cc22[22][6]],
            index = ['Sem0 2021','Sem1 2021','Sem2 2021','Sem3 2021','Sem4 2021','Sem5 2021','Sem6 2021','Sem7 2021','Sem8 2021',
                    'Sem9 2021','Sem10 2021','Sem11 2021','Sem12 2021','Sem13 2021','Sem14 2021','Sem15 2021','Sem 16 2021',
                    'Sem 17 2021','Sem 18 2021','Sem 19 2021','Sem 20 2021','Sem 21 2021',
                    'Sem0 2022','Sem1 2022','Sem2 2022','Sem3 2022','Sem4 2022','Sem5 2022','Sem6 2022','Sem7 2022','Sem8 2021',
                    'Sem9 2022','Sem10 2022','Sem11 2022','Sem12 2022','Sem13 2022','Sem14 2022','Sem15 2022','Sem16 2022',
                    'Sem17 2022','Sem18 2022','Sem19 2022','Sem20 2022','Sem21 2022','Sem22 2022'])
#unir en dataframe
CoefCorrel = pd.concat([s1, s2, s3, s4, s5, s6, s7], axis = 1)
CoefCorrel.columns = [ 'r_Tp_Th', 'p_Tp_Th', 'r_Tp_Tc', 'p_Tp_Tc', 'r_Tp_Te', 'p_Tp_Te', 'nº datos']
display(CoefCorrel)
CoefCorrel.describe()
# Out:
#               r_Tp_Th        p_Tp_Th   r_Tp_Tc        p_Tp_Tc   r_Tp_Te  \
# Sem0 2021   -0.080781   5.265960e-02 -0.027667   5.075269e-01  0.093742
# Sem1 2021   -0.239793   3.041099e-10  0.130287   7.102735e-04 -0.013262
# Sem2 2021    0.204077   9.465316e-08  0.076514   4.740216e-02 -0.084375
# Sem3 2021    0.309994   1.960603e-16  0.034067   3.779236e-01  0.164662
# Sem4 2021    0.296845   3.884740e-15  0.085186   2.723248e-02  0.302597
# Sem5 2021    0.611197   4.524550e-70 -0.214820   1.863731e-08  0.037165
# Sem6 2021    0.308322   2.890733e-16 -0.024492   5.261922e-01  0.244283
# Sem7 2021    0.699519  7.433251e-100  0.243883   1.480145e-10  0.062507
# Sem8 2021    0.522486   2.425014e-48  0.436197   1.382781e-32 -0.211661
# Sem9 2021    0.692492   4.324693e-97  0.527061   2.611412e-49  0.257538
# Sem10 2021   0.773676  1.013607e-134  0.677602   2.361553e-91  0.283083
# Sem11 2021   0.691769   8.240027e-97  0.703583  1.718478e-101  0.408562
# ...

# %%
ordenar_valores_cc (CoefCorrel, 'r_Tp_Th', 'p_Tp_Th', 'r_Tp_Tc', 'p_Tp_Tc', 'r_Tp_Te', 'p_Tp_Te')
# Out:
# CC menor que -1, problemas en el código
# CC menor que -1, problemas en el código
#          r_Tp_Th  r_Tp_Tc  r_Tp_Te
# cc>0.5        15       14        2
# cc>0          13       23       30
# cc>-0.5       11        6       11
# cc>-1          6        0        2
# total         45       43       45

# %% [markdown]
# # 3.2) ¿Las ocilaciones llegan/vienen de polícromos? Coef a partir de las temperaturas suavizadas

# %% [markdown]
# ### Obtener coeficientes:

# %%
#Función adaptada para variables suavizadas
def cc_Th_Tc_Te_Tp(DataframeCruce, DataframeExterior, DataframeHall, DatosPolicromos):
    """
    Atributos:
    1) DataframeCruce: Lista de dataframes por semanas correspondiente a los datos de un mes de Cruce
    2) DataframeExterior: Lista de dataframes por semanas correspondiente a los datos de un mes de Exterior
    3) DataframeHall: Lista de dataframes por semanas correspondiente a los datos de un mes de Hall
    4) DatosPolicromos: Lista de dataframes por semanas correspondiente a los datos de un mes de Policromos
    
    Devuelve:
    Una lista de listas, r. Cada elemento de r, r[i] con i=0, 1, 2, 3, 4, es una lista con los coeficiente de correlación y p 
    valores correspondientes a una semana.  r[i] = r_Tp_Th, p_Tp_Th, r_Tp_Tc, p_Tp_Tc, r_Tp_Te, p_Tp_Te
    
    ¿A qué corresponde cada elemento de r[i]?
    1) r_Tp_Th: Coeficiente de correlación entre la temperatura de Policromos y del Hall
    2) p_Tp_Th: P-valor correspondiente a r_Tp_Th
    3) r_Tp_Tc: Coeficiente de correlación entre la temperatura de Policromos y del Cruce
    4) p_Tp_Tc: P-valor correspondiente a r_Tp_Tc
    5) r_Tp_Te: Coeficiente de correlación entre la temperatura de Policromos y la exterior
    6) p_Tp_Te: P-valor correspondiente a r_Tp_Te
    """
    i=0
    r=[]
    while i<len(DataframeCruce):
       #print(i)
        DataframeCruce[i].reset_index(drop=True, inplace=True)
        DataframeExterior[i].reset_index(drop=True, inplace=True)
        DataframeHall[i].reset_index(drop=True, inplace=True)
        DatosPolicromos[i].reset_index(drop=True, inplace=True)
        
        # Variables que me van a hacer falta: Tp_Th, Tp_Tc, Tp_Te
        if DataframeCruce[i]['CO2 D (ppm)'].isna().all() :
#             print('No datos en cruce')
            for index, _ in DataframeExterior[i].iterrows():#Se va fuera de indice
                if  __builtins__.sum([pd.isna(DataframeHall[i]['Th_suavizada'][index]),
                                      pd.isna(DataframeExterior[i]['Te_suavizada'][index]),
                                      pd.isna(DatosPolicromos[i]['Tp_suavizada'][index])]) > 0:
    #                 DataframeCruce[i].drop([index], axis=0, inplace=True)
                    DataframeExterior[i].drop([index], axis=0, inplace=True)
                    DataframeHall[i].drop([index], axis=0, inplace=True)
                    DatosPolicromos[i].drop([index], axis=0, inplace=True)

            #Mediante scipy por semanas:
            r_Tp_Th, p_Tp_Th = stats.pearsonr(DatosPolicromos[i]['Tp_suavizada'], DataframeHall[i]['Th_suavizada'])
    #         r_Tp_Tc, p_Tp_Tc = stats.pearsonr(DatosPolicromos[i]['Tp_suavizada'], DataframeCruce[i]['Tc_suavizada'])
            r_Tp_Te, p_Tp_Te = stats.pearsonr(DatosPolicromos[i]['Tp_suavizada'], DataframeExterior[i]['Te_suavizada'])
            rs = r_Tp_Th, p_Tp_Th, np.nan, np.nan, r_Tp_Te, p_Tp_Te, len(DatosPolicromos[i]['Tp_suavizada'])
        
        else:
#             print('si datos en cruce')
            for index, _ in DataframeExterior[i].iterrows():#Se va fuera de indice
                if  __builtins__.sum([pd.isna(DataframeCruce[i]['Tc_suavizada'][index]),
                                      pd.isna(DataframeHall[i]['Th_suavizada'][index]),
                                      pd.isna(DataframeExterior[i]['Te_suavizada'][index]),
                                      pd.isna(DatosPolicromos[i]['Tp_suavizada'][index])]) > 0:
                    DataframeCruce[i].drop([index], axis=0, inplace=True)
                    DataframeExterior[i].drop([index], axis=0, inplace=True)
                    DataframeHall[i].drop([index], axis=0, inplace=True)
                    DatosPolicromos[i].drop([index], axis=0, inplace=True)

            #Mediante scipy por semanas:
            r_Tp_Th, p_Tp_Th = stats.pearsonr(DatosPolicromos[i]['Tp_suavizada'], DataframeHall[i]['Th_suavizada'])
            r_Tp_Tc, p_Tp_Tc = stats.pearsonr(DatosPolicromos[i]['Tp_suavizada'], DataframeCruce[i]['Tc_suavizada'])
            r_Tp_Te, p_Tp_Te = stats.pearsonr(DatosPolicromos[i]['Tp_suavizada'], DataframeExterior[i]['Te_suavizada'])
            rs = r_Tp_Th, p_Tp_Th, r_Tp_Tc, p_Tp_Tc, r_Tp_Te, p_Tp_Te, len(DatosPolicromos[i]['Tp_suavizada'])
        r.append(rs)
        i=i+1
    return(r)

# %%
cc21 = cc_Th_Tc_Te_Tp(SemanaCruce21, SemanaExterior21, SemanaHall21, PolicromosSemanas_2021)
cc22 = cc_Th_Tc_Te_Tp(SemanaCruce22, SemanaExterior22, SemanaHall22, PolicromosSemanas_2022)

# %%
s1=pd.Series([cc21[0][0], cc21[1][0],cc21[2][0],cc21[3][0],cc21[4][0],cc21[5][0],cc21[6][0],cc21[7][0],cc21[8][0],cc21[9][0],
              cc21[10][0], cc21[11][0], cc21[12][0], cc21[13][0], cc21[14][0], cc21[15][0], cc21[16][0], cc21[17][0],
              cc21[18][0],cc21[19][0],cc21[20][0],cc21[21][0],
              cc22[0][0], cc22[1][0],cc22[2][0],cc22[3][0],cc22[4][0],cc22[5][0],cc22[6][0],cc22[7][0],cc22[8][0],
              cc22[9][0], cc22[10][0], cc22[11][0], cc22[12][0], cc22[13][0], cc22[14][0], cc22[15][0], cc22[16][0],
              cc22[17][0], cc22[18][0], cc22[19][0], cc22[20][0], cc22[21][0], cc22[22][0]],
            index = ['Sem0 2021','Sem1 2021','Sem2 2021','Sem3 2021','Sem4 2021','Sem5 2021','Sem6 2021','Sem7 2021','Sem8 2021',
                    'Sem9 2021','Sem10 2021','Sem11 2021','Sem12 2021','Sem13 2021','Sem14 2021','Sem15 2021','Sem 16 2021',
                    'Sem 17 2021','Sem 18 2021','Sem 19 2021','Sem 20 2021','Sem 21 2021',
                    'Sem0 2022','Sem1 2022','Sem2 2022','Sem3 2022','Sem4 2022','Sem5 2022','Sem6 2022','Sem7 2022','Sem8 2021',
                    'Sem9 2022','Sem10 2022','Sem11 2022','Sem12 2022','Sem13 2022','Sem14 2022','Sem15 2022','Sem16 2022',
                    'Sem17 2022','Sem18 2022','Sem19 2022','Sem20 2022','Sem21 2022','Sem22 2022'])
s2=pd.Series([cc21[0][1], cc21[1][1],cc21[2][1],cc21[3][1],cc21[4][1],cc21[5][1],cc21[6][1],cc21[7][1],cc21[8][1],cc21[9][1],
              cc21[10][1], cc21[11][1], cc21[12][1], cc21[13][1], cc21[14][1], cc21[15][1], cc21[16][1], cc21[17][1], 
              cc21[18][1],cc21[19][1],cc21[20][1],cc21[21][1],
              cc22[0][1], cc22[1][1],cc22[2][1],cc22[3][1],cc22[4][1],cc22[5][1],cc22[6][1],cc22[7][1],cc22[8][1],
              cc22[9][1], cc22[10][1], cc22[11][1], cc22[12][1], cc22[13][1], cc22[14][1], cc22[15][1], cc22[16][1],
              cc22[17][1], cc22[18][1], cc22[19][1], cc22[20][1], cc22[21][1], cc22[22][1]],
            index = ['Sem0 2021','Sem1 2021','Sem2 2021','Sem3 2021','Sem4 2021','Sem5 2021','Sem6 2021','Sem7 2021','Sem8 2021',
                    'Sem9 2021','Sem10 2021','Sem11 2021','Sem12 2021','Sem13 2021','Sem14 2021','Sem15 2021','Sem 16 2021',
                    'Sem 17 2021','Sem 18 2021','Sem 19 2021','Sem 20 2021','Sem 21 2021',
                    'Sem0 2022','Sem1 2022','Sem2 2022','Sem3 2022','Sem4 2022','Sem5 2022','Sem6 2022','Sem7 2022','Sem8 2021',
                    'Sem9 2022','Sem10 2022','Sem11 2022','Sem12 2022','Sem13 2022','Sem14 2022','Sem15 2022','Sem16 2022',
                    'Sem17 2022','Sem18 2022','Sem19 2022','Sem20 2022','Sem21 2022','Sem22 2022'])
s3=pd.Series([cc21[0][2], cc21[1][2],cc21[2][2],cc21[3][2],cc21[4][2],cc21[5][2],cc21[6][2],cc21[7][2],cc21[8][2],cc21[9][2],
              cc21[10][2], cc21[11][2], cc21[12][2], cc21[13][2], cc21[14][2], cc21[15][2], cc21[16][2], cc21[17][2],
              cc21[18][2],cc21[19][2],cc21[20][2],cc21[21][2], 
              cc22[0][2], cc22[1][2],cc22[2][2],cc22[3][2],cc22[4][2],cc22[5][2],cc22[6][2],cc22[7][2],cc22[8][2],
              cc22[9][2], cc22[10][2], cc22[11][2], cc22[12][2], cc22[13][2], cc22[14][2], cc22[15][2], cc22[16][2],
              cc22[17][2], cc22[18][2], cc22[19][2], cc22[20][2], cc22[21][2], cc22[22][2]],
            index = ['Sem0 2021','Sem1 2021','Sem2 2021','Sem3 2021','Sem4 2021','Sem5 2021','Sem6 2021','Sem7 2021','Sem8 2021',
                    'Sem9 2021','Sem10 2021','Sem11 2021','Sem12 2021','Sem13 2021','Sem14 2021','Sem15 2021','Sem 16 2021',
                    'Sem 17 2021','Sem 18 2021','Sem 19 2021','Sem 20 2021','Sem 21 2021',
                    'Sem0 2022','Sem1 2022','Sem2 2022','Sem3 2022','Sem4 2022','Sem5 2022','Sem6 2022','Sem7 2022','Sem8 2021',
                    'Sem9 2022','Sem10 2022','Sem11 2022','Sem12 2022','Sem13 2022','Sem14 2022','Sem15 2022','Sem16 2022',
                    'Sem17 2022','Sem18 2022','Sem19 2022','Sem20 2022','Sem21 2022','Sem22 2022'])
s4=pd.Series([cc21[0][3], cc21[1][3],cc21[2][3],cc21[3][3],cc21[4][3],cc21[5][3],cc21[6][3],cc21[7][3],cc21[8][3],cc21[9][3],
              cc21[10][3], cc21[11][3], cc21[12][3], cc21[13][3], cc21[14][3], cc21[15][3], cc21[16][3], cc21[17][3],
              cc21[18][3],cc21[19][3],cc21[20][3],cc21[21][3],
              cc22[0][3], cc22[1][3],cc22[2][3],cc22[3][3],cc22[4][3],cc22[5][3],cc22[6][3],cc22[7][3],cc22[8][3],
              cc22[9][3], cc22[10][3], cc22[11][3], cc22[12][3], cc22[13][3], cc22[14][3], cc22[15][3], cc22[16][3],
              cc22[17][3], cc22[18][3], cc22[19][3], cc22[20][3], cc22[21][3], cc22[22][3]],
            index = ['Sem0 2021','Sem1 2021','Sem2 2021','Sem3 2021','Sem4 2021','Sem5 2021','Sem6 2021','Sem7 2021','Sem8 2021',
                    'Sem9 2021','Sem10 2021','Sem11 2021','Sem12 2021','Sem13 2021','Sem14 2021','Sem15 2021','Sem 16 2021',
                    'Sem 17 2021','Sem 18 2021','Sem 19 2021','Sem 20 2021','Sem 21 2021',
                    'Sem0 2022','Sem1 2022','Sem2 2022','Sem3 2022','Sem4 2022','Sem5 2022','Sem6 2022','Sem7 2022','Sem8 2021',
                    'Sem9 2022','Sem10 2022','Sem11 2022','Sem12 2022','Sem13 2022','Sem14 2022','Sem15 2022','Sem16 2022',
                    'Sem17 2022','Sem18 2022','Sem19 2022','Sem20 2022','Sem21 2022','Sem22 2022'])
s5=pd.Series([cc21[0][4], cc21[1][4],cc21[2][4],cc21[3][4],cc21[4][4],cc21[5][4],cc21[6][4],cc21[7][4],cc21[8][4],cc21[9][4],
              cc21[10][4], cc21[11][4], cc21[12][4], cc21[13][4], cc21[14][4], cc21[15][4], cc21[16][4], cc21[17][4], 
              cc21[18][4],cc21[19][4],cc21[20][4],cc21[21][4],
              cc22[0][4], cc22[1][4],cc22[2][4],cc22[3][4],cc22[4][4],cc22[5][4],cc22[6][4],cc22[7][4],cc22[8][4],
              cc22[9][4], cc22[10][4], cc22[11][4], cc22[12][4], cc22[13][4], cc22[14][4], cc22[15][0], cc22[16][4],
              cc22[17][4], cc22[18][4], cc22[19][4], cc22[20][4], cc22[21][4], cc22[22][4]],
            index = ['Sem0 2021','Sem1 2021','Sem2 2021','Sem3 2021','Sem4 2021','Sem5 2021','Sem6 2021','Sem7 2021','Sem8 2021',
                    'Sem9 2021','Sem10 2021','Sem11 2021','Sem12 2021','Sem13 2021','Sem14 2021','Sem15 2021','Sem 16 2021',
                    'Sem 17 2021','Sem 18 2021','Sem 19 2021','Sem 20 2021','Sem 21 2021',
                    'Sem0 2022','Sem1 2022','Sem2 2022','Sem3 2022','Sem4 2022','Sem5 2022','Sem6 2022','Sem7 2022','Sem8 2021',
                    'Sem9 2022','Sem10 2022','Sem11 2022','Sem12 2022','Sem13 2022','Sem14 2022','Sem15 2022','Sem16 2022',
                    'Sem17 2022','Sem18 2022','Sem19 2022','Sem20 2022','Sem21 2022','Sem22 2022'])
s6=pd.Series([cc21[0][5], cc21[1][5],cc21[2][5],cc21[3][5],cc21[4][5],cc21[5][5],cc21[6][5],cc21[7][5],cc21[8][5],cc21[9][5],
              cc21[10][5], cc21[11][5], cc21[12][5], cc21[13][5], cc21[14][5], cc21[15][5], cc21[16][5], cc21[17][5], 
              cc21[18][5],cc21[19][5],cc21[20][5],cc21[21][5],
              cc22[0][5], cc22[1][5],cc22[2][5],cc22[3][5],cc22[4][5],cc22[5][5],cc22[6][5],cc22[7][5],cc22[8][5],
              cc22[9][5], cc22[10][5], cc22[11][5], cc22[12][5], cc22[13][5], cc22[14][5], cc22[15][5], cc22[16][5],
              cc22[17][5], cc22[18][5], cc22[19][5], cc22[20][5], cc22[21][5], cc22[22][5]],
            index = ['Sem0 2021','Sem1 2021','Sem2 2021','Sem3 2021','Sem4 2021','Sem5 2021','Sem6 2021','Sem7 2021','Sem8 2021',
                    'Sem9 2021','Sem10 2021','Sem11 2021','Sem12 2021','Sem13 2021','Sem14 2021','Sem15 2021','Sem 16 2021',
                    'Sem 17 2021','Sem 18 2021','Sem 19 2021','Sem 20 2021','Sem 21 2021',
                    'Sem0 2022','Sem1 2022','Sem2 2022','Sem3 2022','Sem4 2022','Sem5 2022','Sem6 2022','Sem7 2022','Sem8 2021',
                    'Sem9 2022','Sem10 2022','Sem11 2022','Sem12 2022','Sem13 2022','Sem14 2022','Sem15 2022','Sem16 2022',
                    'Sem17 2022','Sem18 2022','Sem19 2022','Sem20 2022','Sem21 2022','Sem22 2022'])
s7=pd.Series([cc21[0][6], cc21[1][6],cc21[2][6],cc21[3][6],cc21[4][6],cc21[5][6],cc21[6][6],cc21[7][6],cc21[8][6],cc21[9][6],
              cc21[10][6], cc21[11][6], cc21[12][6], cc21[13][6], cc21[14][6], cc21[15][6], cc21[16][6], cc21[17][6], 
              cc21[18][6],cc21[19][6],cc21[20][6],cc21[21][6],
              cc22[0][6], cc22[1][6],cc22[2][6],cc22[3][6],cc22[4][6],cc22[5][6],cc22[6][6],cc22[7][6],cc22[8][6],
              cc22[9][6], cc22[10][6], cc22[11][6], cc22[12][6], cc22[13][6], cc22[14][6], cc22[15][6], cc22[16][6],
              cc22[17][6], cc22[18][6], cc22[19][6], cc22[20][6], cc22[21][6], cc22[22][6]],
            index = ['Sem0 2021','Sem1 2021','Sem2 2021','Sem3 2021','Sem4 2021','Sem5 2021','Sem6 2021','Sem7 2021','Sem8 2021',
                    'Sem9 2021','Sem10 2021','Sem11 2021','Sem12 2021','Sem13 2021','Sem14 2021','Sem15 2021','Sem 16 2021',
                    'Sem 17 2021','Sem 18 2021','Sem 19 2021','Sem 20 2021','Sem 21 2021',
                    'Sem0 2022','Sem1 2022','Sem2 2022','Sem3 2022','Sem4 2022','Sem5 2022','Sem6 2022','Sem7 2022','Sem8 2021',
                    'Sem9 2022','Sem10 2022','Sem11 2022','Sem12 2022','Sem13 2022','Sem14 2022','Sem15 2022','Sem16 2022',
                    'Sem17 2022','Sem18 2022','Sem19 2022','Sem20 2022','Sem21 2022','Sem22 2022'])
#unir en dataframe
CoefCorrel = pd.concat([s1, s2, s3, s4, s5, s6, s7], axis = 1)
CoefCorrel.columns = ['r_Tp_Th', 'p_Tp_Th', 'r_Tp_Tc', 'p_Tp_Tc', 'r_Tp_Te', 'p_Tp_Te', 'nº datos']
display(CoefCorrel)
CoefCorrel.describe()
# Out:
#               r_Tp_Th        p_Tp_Th   r_Tp_Tc        p_Tp_Tc   r_Tp_Te  \
# Sem0 2021    0.053743   1.997215e-01  0.033793   4.202636e-01  0.085286
# Sem1 2021   -0.290730   1.479932e-14  0.283865   6.394976e-14 -0.010802
# Sem2 2021    0.242516   1.885621e-10  0.211358   3.176047e-08 -0.071203
# Sem3 2021    0.360188   5.142546e-22  0.054621   1.572532e-01  0.139690
# Sem4 2021    0.330761   1.717013e-18  0.006271   8.715726e-01  0.307244
# Sem5 2021    0.624608   7.131505e-74 -0.234069   8.388040e-10  0.101061
# Sem6 2021    0.330757   1.281844e-18 -0.061848   1.091913e-01  0.232987
# Sem7 2021    0.749707  3.068674e-122  0.357130   1.205086e-21  0.063380
# Sem8 2021    0.601544   7.006886e-67  0.641605   1.214067e-78 -0.237363
# Sem9 2021    0.701642  1.046648e-100  0.614213   6.204441e-71  0.260424
# Sem10 2021   0.809381  1.250518e-155  0.759208  5.758118e-126  0.296108
# Sem11 2021   0.706622  9.839416e-103  0.740512  9.439387e-118  0.421687
# ...

# %%
ordenar_valores_cc (CoefCorrel, 'r_Tp_Th', 'p_Tp_Th', 'r_Tp_Tc', 'p_Tp_Tc', 'r_Tp_Te', 'p_Tp_Te')
# Out:
# CC menor que -1, problemas en el código
# CC menor que -1, problemas en el código
#          r_Tp_Th  r_Tp_Tc  r_Tp_Te
# cc>0.5        15       19        2
# cc>0          14       17       31
# cc>-0.5        9        7       10
# cc>-1          7        0        2
# total         45       43       45
